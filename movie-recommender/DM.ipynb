# %% [markdown]
# Dataset: Netflix-inspired Movie Watch History (7501 user sessions, up to 10 movies each)

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import pandas as pd
from itertools import combinations
from collections import defaultdict
import warnings
warnings.filterwarnings('ignore')

# %%
dataset = pd.read_csv('movies_dataset.csv', header=None)
dataset.head()
# Out:
#               0                1                        2              3  \
# 0      Iron Man         Twilight  Guardians of the Galaxy   The Avengers
# 1         Shrek              NaN                      NaN            NaN
# 2  Man of Steel            Logan          The Dark Knight       Deadpool
# 3  The Avengers  The Dark Knight           Doctor Strange          Logan
# 4       Ant-Man  Captain America           Doctor Strange  Black Panther
#
#                          4             5                  6      7      8    9
# 0                 Avengers           NaN                NaN    NaN    NaN  NaN
# 1                      NaN           NaN                NaN    NaN    NaN  NaN
# 2                  Aquaman  Wonder Woman  Batman v Superman  Venom  Joker  NaN
# 3  Guardians of the Galaxy         Joker               Thor    NaN    NaN  NaN
# 4                 Iron Man          Thor                NaN    NaN    NaN  NaN

# %%
dataset.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7501 entries, 0 to 7500
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       7501 non-null   str
#  1   1       6350 non-null   str
#  2   2       5249 non-null   str
#  3   3       4037 non-null   str
#  4   4       3278 non-null   str
#  5   5       2636 non-null   str
#  6   6       1942 non-null   str
#  7   7       1230 non-null   str
#  8   8       745 non-null    str
#  9   9       339 non-null    str
# dtypes: str(10)
# memory usage: 586.1 KB

# %%
dataset.values
# Out:
# array([['Iron Man', 'Twilight', 'Guardians of the Galaxy', ..., nan, nan,
#         nan],
#        ['Shrek', nan, nan, ..., nan, nan, nan],
#        ['Man of Steel', 'Logan', 'The Dark Knight', ..., 'Venom',
#         'Joker', nan],
#        ...,
#        ['Mission: Impossible', nan, nan, ..., nan, nan, nan],
#        ['Twilight', 'Mad Max: Fury Road', 'John Wick', ..., nan, nan,
#         nan],
#        ['Twilight', nan, nan, ..., nan, nan, nan]],
#       shape=(7501, 10), dtype=object)

# %%
dataset = dataset.replace('Avengers', 'The Avengers')
dataset.head()
# Out:
#               0                1                        2              3  \
# 0      Iron Man         Twilight  Guardians of the Galaxy   The Avengers
# 1         Shrek              NaN                      NaN            NaN
# 2  Man of Steel            Logan          The Dark Knight       Deadpool
# 3  The Avengers  The Dark Knight           Doctor Strange          Logan
# 4       Ant-Man  Captain America           Doctor Strange  Black Panther
#
#                          4             5                  6      7      8    9
# 0             The Avengers           NaN                NaN    NaN    NaN  NaN
# 1                      NaN           NaN                NaN    NaN    NaN  NaN
# 2                  Aquaman  Wonder Woman  Batman v Superman  Venom  Joker  NaN
# 3  Guardians of the Galaxy         Joker               Thor    NaN    NaN  NaN
# 4                 Iron Man          Thor                NaN    NaN    NaN  NaN

# %%
dataset.values
# Out:
# array([['Iron Man', 'Twilight', 'Guardians of the Galaxy', ..., nan, nan,
#         nan],
#        ['Shrek', nan, nan, ..., nan, nan, nan],
#        ['Man of Steel', 'Logan', 'The Dark Knight', ..., 'Venom',
#         'Joker', nan],
#        ...,
#        ['Mission: Impossible', nan, nan, ..., nan, nan, nan],
#        ['Twilight', 'Mad Max: Fury Road', 'John Wick', ..., nan, nan,
#         nan],
#        ['Twilight', nan, nan, ..., nan, nan, nan]],
#       shape=(7501, 10), dtype=object)

# %% [markdown]
# ## Preprocessing

# %%
import pickle

transactions = []
for i in range(0, 7501):
    transactions.append([str(dataset.values[i, j])
                         for j in range(0, 10)
                         if pd.notna(dataset.values[i, j])])

with open("transactions.pkl", "wb") as f:
    pickle.dump(transactions, f)

# %%
import pickle

with open("transactions.pkl", "rb") as f:
    transactions = pickle.load(f)
    print(transactions)
# Out:
# [['Iron Man', 'Twilight', 'Guardians of the Galaxy', 'The Avengers', 'The Avengers'], ['Shrek'], ['Man of Steel', 'Logan', 'The Dark Knight', 'Deadpool', 'Aquaman', 'Wonder Woman', 'Batman v Superman', 'Venom', 'Joker'], ['The Avengers', 'The Dark Knight', 'Doctor Strange', 'Logan', 'Guardians of the Galaxy', 'Joker', 'Thor'], ['Ant-Man', 'Captain America', 'Doctor Strange', 'Black Panther', 'Iron Man', 'Thor'], ['WALL-E', 'Toy Story'], ['The Hunger Games', 'Jurassic Park', 'Interstellar', 'Star Wars', 'John Wick', 'Mission: Impossible', 'Mad Max: Fury Road', 'Inception', 'Avatar', 'The Matrix'], ['La La Land', 'Titanic'], ['Twilight', 'La La Land'], ['Forrest Gump', 'Gone Girl', 'The Godfather', 'Pulp Fiction'], ['Titanic', 'Mad Max: Fury Road', 'Mission: Impossible', 'La La Land', 'John Wick'], ['Frozen', 'WALL-E'], ['The Matrix', 'Inception', 'The Dark Knight', 'Avatar', 'Jurassic Park', 'The Hunger Games', 'Aquaman', 'Venom'], ['The Hunger Games', 'Avatar', 'Inception', 'Forrest Gump', 'Jurassic Park', 'Interstellar', 'The Godfather', 'Fight Club', 'The Matrix', 'Star Wars'], ['Venom', 'Deadpool', 'Logan', 'Aquaman', 'Wonder Woman', 'Joker', 'The Dark Knight'], ['Black Panther', 'The Avengers'], ['Mission: Impossible', 'La La Land', 'John Wick'], ['Thor', 'Guardians of the Galaxy', 'The Avengers', 'Spider-Man', 'Ant-Man'], ['Twilight', 'La La Land', 'Titanic'], ['Batman v Superman', 'Man of Steel', 'Aquaman', 'Joker', 'Logan', 'Wonder Woman', 'Deadpool', 'Venom', 'The Dark Knight'], ['Venom', 'Wonder Woman'], ['Pulp Fiction', 'Mad Max: Fury Road', 'John Wick'], ['John Wick', 'Mission: Impossible', 'Mad Max: Fury Road'], ['Toy Story', 'Coco', 'La La Land', 'Frozen', 'Twilight', 'Finding Nemo'], ['Thor', 'Iron Man', 'Black Panther', 'Doctor Strange', 'Spider-Man', 'Ant-Man', 'The Avengers', 'Captain America', 'Guardians of the Galaxy', 'The Avengers'], ['Wonder Woman', 'Logan', 'Aquaman', 'Venom', 'Deadpool'], ['Deadpool', 'Logan', 'Man of Steel', 'Batman v Superman', 'Wonder Woman', 'Joker', 'Venom', 'Aquaman'], ['Twilight'], ['Titanic'], ['Guardians of the Galaxy', 'John Wick', 'The Avengers', 'Spider-Man'], ['Wonder Woman', 'Logan', 'Deadpool', 'Man of Steel', 'Batman v Superman'], ['Fight Club', 'Whiplash'], ['Iron Man', 'Captain America', 'The Avengers'], ['The Lion King'], ['Coco', 'The Lion King', 'Up', 'WALL-E', 'Finding Nemo'], ['Interstellar', 'Avatar'], ['Doctor Strange', 'Twilight', 'Thor', 'Spider-Man', 'The Avengers', 'Guardians of the Galaxy'], ['Whiplash'], ['Gone Girl'], ['Ant-Man', 'The Avengers', 'Iron Man', 'Captain America', 'The Lion King', 'The Avengers', 'Black Panther', 'Spider-Man', 'Frozen', 'Guardians of the Galaxy'], ['La La Land', 'Titanic'], ['Titanic', 'Twilight', 'La La Land'], ['Thor', 'John Wick', 'The Avengers', 'Black Panther', 'The Avengers', 'Iron Man', 'Captain America', 'Guardians of the Galaxy'], ['Jurassic Park'], ['Batman v Superman', 'Aquaman', 'Wonder Woman', 'The Dark Knight', 'Deadpool', 'Man of Steel', 'Joker', 'Venom'], ['Deadpool', 'Wonder Woman', 'Doctor Strange', 'The Dark Knight', 'Spider-Man'], ['Avatar', 'Inception', 'La La Land', 'The Hunger Games'], ['Black Panther', 'Ant-Man'], ['John Wick', 'Guardians of the Galaxy', 'Black Panther', 'Captain America', 'Mad Max: Fury Road', 'Spider-Man'], ['Frozen'], ['Twilight'], ['Avatar', 'Jurassic Park', 'Star Wars', 'The Matrix', 'Interstellar'], ['John Wick'], ['The Dark Knight', 'Deadpool'], ['Venom', 'Twilight', 'The Dark Knight', 'Batman v Superman'], ['Star Wars', 'The Matrix', 'Jurassic Park', 'The Hunger Games', 'Interstellar', 'Inception', 'Avatar'], ['The Lion King', 'Finding Nemo', 'Up', 'Coco'], ['Man of Steel', 'Wonder Woman', 'Deadpool', 'The Dark Knight'], ['John Wick'], ['Gone Girl', 'The Godfather', 'Pulp Fiction', 'Fight Club'], ['Avatar', 'The Hunger Games'], ['Pulp Fiction', 'Gone Girl', 'Whiplash', 'Forrest Gump'], ['Pulp Fiction', 'Captain America', 'Fight Club', 'The Avengers', 'Whiplash', 'Black Panther', ...

# %% [markdown]
# ## Visualization 1: Genre Distribution

# %%
genre_map = {
    'Inception': 'Sci-Fi', 'The Dark Knight': 'Action', 'Interstellar': 'Sci-Fi',
    'The Matrix': 'Sci-Fi', 'Avengers': 'Action', 'Iron Man': 'Action',
    'Joker': 'Drama', 'Parasite': 'Thriller', 'The Godfather': 'Crime',
    'Pulp Fiction': 'Crime', 'Fight Club': 'Drama', 'Forrest Gump': 'Drama',
    'The Lion King': 'Animation', 'Titanic': 'Romance', 'Avatar': 'Sci-Fi',
    'Toy Story': 'Animation', 'The Avengers': 'Action', 'Black Panther': 'Action',
    'Guardians of the Galaxy': 'Action', 'Spider-Man': 'Action',
    'Doctor Strange': 'Action', 'Thor': 'Action', 'Captain America': 'Action',
    'Ant-Man': 'Action', 'Shrek': 'Animation', 'Finding Nemo': 'Animation',
    'Up': 'Animation', 'WALL-E': 'Animation', 'Coco': 'Animation', 'Frozen': 'Animation',
    'Harry Potter': 'Fantasy', 'Lord of the Rings': 'Fantasy', 'Star Wars': 'Sci-Fi',
    'Jurassic Park': 'Sci-Fi', 'The Hunger Games': 'Sci-Fi', 'Twilight': 'Romance',
    'Deadpool': 'Action', 'Logan': 'Action', 'Venom': 'Action',
    'Aquaman': 'Action', 'Wonder Woman': 'Action', 'Batman v Superman': 'Action',
    'Man of Steel': 'Action', 'The Social Network': 'Drama', 'Gone Girl': 'Thriller',
    'Whiplash': 'Drama', 'La La Land': 'Romance', 'Mad Max: Fury Road': 'Action',
    'John Wick': 'Action', 'Mission: Impossible': 'Action'
}

# Count genre occurrences
genre_counts = defaultdict(int)
for session in transactions:
    for movie in session:
        genre = genre_map.get(movie, 'Other')
        genre_counts[genre] += 1

genre_df = pd.DataFrame(list(genre_counts.items()), columns=['Genre', 'Count'])
genre_df = genre_df.sort_values('Count', ascending=False)

colors = ['#e63946','#457b9d','#2a9d8f','#e9c46a','#f4a261','#264653','#8338ec']

fig, axes = plt.subplots(1, 2, figsize=(14, 6))
fig.suptitle('Movie Genre Distribution in Watch History', fontsize=16, fontweight='bold')

# Bar chart
axes[0].bar(genre_df['Genre'], genre_df['Count'], color=colors[:len(genre_df)])
axes[0].set_title('Genre Watch Count')
axes[0].set_xlabel('Genre')
axes[0].set_ylabel('Total Watches')
axes[0].tick_params(axis='x', rotation=30)

# Pie chart
axes[1].pie(genre_df['Count'], labels=genre_df['Genre'], autopct='%1.1f%%',
            colors=colors[:len(genre_df)], startangle=140)
axes[1].set_title('Genre Share (%)')

plt.tight_layout()
plt.savefig('genre_distribution.png', dpi=150, bbox_inches='tight')
plt.show()
print("Genre Distribution saved.")
# Out:
# Genre Distribution saved.

# %% [markdown]
# ## Visualization 2: Top 20 Most Watched Movies

# %%
from collections import Counter

all_movies = [movie for session in transactions for movie in session]
movie_counts = Counter(all_movies)
top20 = pd.DataFrame(movie_counts.most_common(20), columns=['Movie', 'Count'])

plt.figure(figsize=(12, 6))
bars = plt.barh(top20['Movie'][::-1], top20['Count'][::-1],
                color=plt.cm.viridis([i/20 for i in range(20)]))
plt.title('Top 20 Most Watched Movies', fontsize=14, fontweight='bold')
plt.xlabel('Watch Count')
plt.tight_layout()
plt.savefig('top20_movies.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Apriori Algorithm — Custom Implementation

# %%
from apyori import apriori

rules = apriori(transactions, min_support=0.003, min_confidence=0.2, min_lift=3, min_length=2)
rules
# Out:
# <generator object apriori at 0x000002126DFC38A0>

# %%
rules_list = list(rules)
rules_list
# Out:
# [RelationRecord(items=frozenset({'Ant-Man', 'Black Panther'}), support=0.04906012531662445, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Ant-Man'}), items_add=frozenset({'Black Panther'}), confidence=0.5542168674698795, lift=6.260814341704166), OrderedStatistic(items_base=frozenset({'Black Panther'}), items_add=frozenset({'Ant-Man'}), confidence=0.5542168674698795, lift=6.260814341704166)]),
#  RelationRecord(items=frozenset({'Ant-Man', 'Captain America'}), support=0.051593120917211036, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Ant-Man'}), items_add=frozenset({'Captain America'}), confidence=0.5828313253012049, lift=6.236544609250125), OrderedStatistic(items_base=frozenset({'Captain America'}), items_add=frozenset({'Ant-Man'}), confidence=0.5520684736091298, lift=6.236544609250124)]),
#  RelationRecord(items=frozenset({'Doctor Strange', 'Ant-Man'}), support=0.045327289694707375, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Ant-Man'}), items_add=frozenset({'Doctor Strange'}), confidence=0.5120481927710844, lift=5.918140976850392), OrderedStatistic(items_base=frozenset({'Doctor Strange'}), items_add=frozenset({'Ant-Man'}), confidence=0.5238828967642527, lift=5.918140976850391)]),
#  RelationRecord(items=frozenset({'Ant-Man', 'Guardians of the Galaxy'}), support=0.04879349420077323, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Ant-Man'}), items_add=frozenset({'Guardians of the Galaxy'}), confidence=0.5512048192771085, lift=6.180250148576369), OrderedStatistic(items_base=frozenset({'Guardians of the Galaxy'}), items_add=frozenset({'Ant-Man'}), confidence=0.547085201793722, lift=6.180250148576369)]),
#  RelationRecord(items=frozenset({'Ant-Man', 'Iron Man'}), support=0.04959338754832689, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Ant-Man'}), items_add=frozenset({'Iron Man'}), confidence=0.5602409638554217, lift=6.179952161587526), OrderedStatistic(items_base=frozenset({'Iron Man'}), items_add=frozenset({'Ant-Man'}), confidence=0.5470588235294117, lift=6.179952161587527)]),
#  RelationRecord(items=frozenset({'Spider-Man', 'Ant-Man'}), support=0.04999333422210372, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Ant-Man'}), items_add=frozenset({'Spider-Man'}), confidence=0.5647590361445783, lift=6.360747042222946), OrderedStatistic(items_base=frozenset({'Spider-Man'}), items_add=frozenset({'Ant-Man'}), confidence=0.5630630630630631, lift=6.360747042222946)]),
#  RelationRecord(items=frozenset({'The Avengers', 'Ant-Man'}), support=0.06625783228902812, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Ant-Man'}), items_add=frozenset({'The Avengers'}), confidence=0.7484939759036144, lift=5.752513640628086), OrderedStatistic(items_base=frozenset({'The Avengers'}), items_add=frozenset({'Ant-Man'}), confidence=0.5092213114754098, lift=5.752513640628086)]),
#  RelationRecord(items=frozenset({'Ant-Man', 'Thor'}), support=0.04906012531662445, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Ant-Man'}), items_add=frozenset({'Thor'}), confidence=0.5542168674698795, lift=6.251399583295588), OrderedStatistic(items_base=frozenset({'Thor'}), items_add=frozenset({'Ant-Man'}), confidence=0.5533834586466165, lift=6.251399583295589)]),
#  RelationRecord(items=frozenset({'Aquaman', 'Batman v Superman'}), support=0.04879349420077323, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Aquaman'}), items_add=frozenset({'Batman v Superman'}), confidence=0.5545454545454546, lift=6.560954975623746), OrderedStatistic(items_base=frozenset({'Batman v Superman'}), items_add=frozenset({'Aquaman'}), confidence=0.5772870662460569, lift=6.560954975623747)]),
#  RelationRecord(items=frozenset({'Deadpool', 'Aquaman'}), support=0.04826023196907079, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Aquaman'}), items_add=frozenset({'Deadpool'}), confidence=0.5484848484848485, lift=6.158959354019234), OrderedStatistic(items_base=frozenset({'Deadpool'}), items_add=frozenset({'Aquaman'}), confidence=0.5419161676646707, lift=6.158959354019235)]),
#  RelationRecord(items=frozenset({'Aquaman', 'Joker'}), support=0.04812691641114518, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Aquaman'}), items_add=frozenset({'Joker'}), confidence=0.546969696969697, lift=6.15115396847031), OrderedStatistic(items_base=frozenset({'Joker'}), items_add=frozenset({'Aquaman'}), confidence=0.5412293853073463, lift=6.151153968470311)]),
#  RelationRecord(items=frozenset({'Aquaman', 'Logan'}), support=0.04932675643247567, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Aquaman'}), items_add=frozenset({'Logan'}), confidence=0.5606060606060607, lift=6.342543077837196), OrderedStatistic(items_base=frozenset({'Logan'}), items_add=frozenset({'Aquaman'}), confidence=0.5580693815987934, lift=6.342543077837196)]),
#  RelationRecord(items=frozenset({'Aquaman', 'Man of Steel'}), support=0.05119317424343421, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Aquaman'}), items_add=frozenset({'Man of Steel'}), confidence=0.5818181818181819, lift=6.61245179063361), OrderedStatistic(items_base=frozenset({'Man of Steel'}), items_add=frozenset({'Aquaman'}), confidence=0.5818181818181819, lift=6.61245179063361)]),
#  RelationRecord(items=frozenset({'Aquaman', 'The Dark Knight'}), support=0.04906012531662445, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Aquaman'}), items_add=frozenset({'The Dark Knight'}), confidence=0.5575757575757576, lift=6.233048819039878), OrderedStatistic(items_base=frozenset({'The Dark Knight'}), items_add=frozenset({'Aquaman'}), confidence=0.5484351713859911, lift=6.233048819039878)]),
#  RelationRecord(items=frozenset({'Aquaman', 'Venom'}), support=0.04626049860018664, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Aquaman'}), items_add=frozenset({'Venom'}), confidence=0.5257575757575758, lift=5.993476558902091), OrderedStatistic(items_base=frozenset({'Venom'}), items_add=frozenset({'Aquaman'}), confidence=0.5273556231003039, lift=5.993476558902091)]),
#  RelationRecord(items=frozenset({'Aquaman', 'Wonder Woman'}), support=0.045460605252632985, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Aquaman'}), items_add=frozenset({'Wonder Woman'}), confidence=0.5166666666666667, lift=6.151613756613758), OrderedStatistic(items_base=frozenset({'Wonder Woman'}), items_add=frozenset({'Aquaman'}), confidence=0.5412698412698413, lift=6.151613756613758)]),
#  RelationRecord(items=frozenset({'Inception', 'Avatar'}), support=0.05679242767630983, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Avatar'}), items_add=frozenset({'Inception'}), confidence=0.5908460471567267, lift=6.376886618305909), OrderedStatistic(items_base=frozenset({'Inception'}), items_add=frozenset({'Avatar'}), confidence=0.6129496402877698, lift=6.376886618305909)]),
#  RelationRecord(items=frozenset({'Interstellar', 'Avatar'}), support=0.0590587921610452, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Avatar'}), items_add=frozenset({'Interstellar'}), confidence=0.6144244105409155, lift=6.279015672298919), OrderedStatistic(items_base=frozenset({'Interstellar'}), items_add=frozenset({'Avatar'}), confidence=0.603542234332425, lift=6.279015672298918)]),
#  RelationRecord(items=frozenset({'Jurassic Park', 'Avatar'}), support=0.05692574323423544, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Avatar'}), items_add=frozenset({'Jurassic Park'}), confidence=0.5922330097087378, lift=6.265641475070864), OrderedStatistic(items_base=frozenset({'Jurassic Park'}), items_add=frozenset({'Avatar'}), confidence=0.6022566995768689, lift=6.265641475070865)]),
#  RelationRecord(items=frozenset({'Star Wars', 'Avatar'}), support=0.05692574323423544, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Avatar'}), items_add=frozenset({'Star Wars'}), confidence=0.5922330097087378, lift=6.346199722607489), OrderedStatistic(items_base=frozenset({'Star Wars'}), items_add=frozenset({'Avatar'}), confidence=0.61, lift=6.346199722607489)]),
#  RelationRecord(items=frozenset({'The Hunger Games', 'Avatar'}), support=0.056525796560458606, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Avatar'}), items_add=frozenset({'The Hunger Games'}), confidence=0.5880721220527045, lift=6.301612839310481), OrderedStatistic(items_base=frozenset({'The Hunger Games'}), items_add=frozenset({'Avatar'}), confidence=0.6057142857142858, lift=6.301612839310482)]),
#  RelationRecord(items=frozenset({'The Matrix', 'Avatar'}), support=0.06012531662445007, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Avatar'}), items_add=frozenset({'The Matrix'}), confidence=0.6255201109570041, lift=6.392406474507476), OrderedStatistic(items_base=frozenset({'The Matrix'}), items_add=frozenset({'Avatar'}), confidence=0.614441416893733, lift=6.392406474507477)]),
#  RelationRecord(items=frozenset({'Deadpool', 'Batman v Superman'}), support=0.04999333422210372, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Batman v Superman'}), items_add=frozenset({'Deadpool'}), confidence=0.5914826498422713, lift=6.641783467764786), OrderedStatistic(items_base=frozenset({'Deadpool'}), items_add=frozenset({'Batman v Superman'}), confidence=0.561377245508982, lift=6.641783467764786)]),
#  RelationRecord(items=frozenset({'Joker', 'Batman v Superman'}), support=0.045193974136781764, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Batman v Superman'}), items_add=frozenset({'Joker'}), confidence=0.5347003154574133, lift=6.013174012362904), OrderedStatistic(items_base=frozenset({'Joker'}), items_add=frozenset({'Batman v Superman'}), confidence=0.5082458770614693, lift=6.013174012362904)]),
#  RelationRecord(items=frozenset({'Logan', 'Batman v Superman'}), support=0.04759365417944274, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Batman v Superman'}), items_add=frozenset({'Logan'}), confidence=0.5630914826498422, lift=6.370662460567822), OrderedStatistic(items_base=frozenset({'Logan'}), items_add=frozenset({'Batman v Superman'}), confidence=0.5384615384615384, lift=6.370662460567823)]),
#  RelationRecord(items=frozenset({'Man of Steel', 'Batman v Superman'}), support=0.047460338621517134, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Batman v Superman'}), items_add=frozenset({'Man of Steel'}), confidence=0.5615141955835963, lift=6.381693910715994), OrderedStatistic(items_base=frozenset({'Man of Steel'}), items_add=frozenset({'Batman v Superman'}), confidence=0.5393939393939394, lift=6.381693910715994)]),
#  RelationRecord(items=frozenset({'The Dark Knight', 'Batman v Superman'}), support=0.04959338754832689, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Batman v Superman'}), items_add=frozenset({'The Dark Knight'}), confidence=0.5867507886435331, lift=6.559191752034489), OrderedStatistic(items_base=frozenset({'The Dark Knight'}), items_add=frozenset({'Batman v Superman'}), confidence=0.5543964232488823, lift=6.559191752034489)]),
#  RelationRecord(items=frozenset({'Venom', 'Batman v Superman'}), support=0.04719370750566591, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Batman v Superman'}), items_add=frozenset({'Venom'}), confidence=0.5583596214511042, lift=6.365129970371934), OrderedStatistic(items_base=frozenset({'Venom'}), items_add=frozenset({'Batman v Superman'}), confidence=0.5379939209726444, lift=6.3651299703719335)]),
#  RelationRecord(items=frozenset({'Wonder Woman', 'Batman v Superman'}), support=0.04666044527396347, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Batman v Superman'}), items_add=frozenset({'Wonder Woman'}), confidence=0.5520504731861199, lift=6.572905713284262), OrderedStatistic(items_base=frozenset({'Wonder Woman'}), items_add=frozenset({'Batman v Superman'}), confidence=0.5555555555555556, lift=6.572905713284262)]),
#  RelationRecord(items=frozenset({'Captain America', 'Black Panther'}), support=0.0523930142647647, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Black Panther'}), items_add=frozenset({'Captain America'}), confidence=0.5918674698795181, lift=6.333235223347026), OrderedStatistic(items_base=frozenset({'Captain America'}), items_add=frozenset({'Black Panther'}), confidence=0.5606276747503567, lift=6.333235223347026)]),
#  RelationRecord(items=frozenset({'Doctor Strange', 'Black Panther'}), support=0.04759365417944274, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Black Panther'}), items_add=frozenset({'Doctor Strange'}), confidence=0.5376506024096386, lift=6.214048025692911), OrderedStatistic(items_base=frozenset({'Doctor Strange'}), items_add=frozenset({'Black Panther'}), confidence=0.5500770416024653, lift=6.21404802569291)]),
#  RelationRecord(items=frozenset({'Guardians of the Galaxy', 'Black Panther'}), support=0.04692707638981469, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Black Panther'}), items_add=frozenset({'Guardians of the Galaxy'}), confidence=0.5301204819277109, lift=5.943847137428638), OrderedStatistic(items_base=frozenset({'Guardians of the Galaxy'}), items_add=frozenset({'Black Panther'}), confidence=0.5261584454409566, lift=5.943847137428638)]),
#  RelationRecord(items=frozenset({'Black Panther', 'Iron Man'}), support=0.051593120917211036, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Black Panther'}), items_add=frozenset({'Iron Man'}), confidence=0.5828313253012049, lift=6.4291437810063785), OrderedStatistic(items_base=frozenset({'Iron Man'}), items_add=frozenset({'Black Panther'}), confidence=0.5691176470588235, lift=6.4291437810063785)]),
#  RelationRecord(items=frozenset({'Spider-Man', 'Black Panther'}), support=0.04892680975869884, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Black Panther'}), items_add=frozenset({'Spider-Man'}), confidence=0.552710843373494, lift=6.22505110532219), OrderedStatistic(items_base=frozenset({'Spider-Man'}), items_add=frozenset({'Black Panther'}), confidence=0.5510510510510511, lift=6.225051105322191)]),
#  RelationRecord(items=frozenset({'The Avengers', 'Black Panther'}), support=0.067324356752433, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Black Panther'}), items_add=frozenset({'The Avengers'}), confidence=0.7605421686746988, lift=5.845109433636185), OrderedStatistic(items_base=frozenset({'The Avengers'}), items_add=frozenset({'Black Panther'}), confidence=0.5174180327868853, lift=5.845109433636185)]),
#  RelationRecord(items=frozenset({'Black Panther', 'Thor'}), support=0.0510598586855086, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Black Panther'}), items_add=frozenset({'Thor'}), confidence=0.5768072289156627, lift=6.506212066310354), OrderedStatistic(items_base=frozenset({'Thor'}), items_add=frozenset({'Black Panther'}), confidence=0.5759398496240602, lift=6.506212066310355)]),
#  RelationRecord(items=frozenset({'Doctor Strange', 'Captain America'}), support=0.05225969870683909, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Captain America'}), items_add=frozenset({'Doctor Strange'}), confidence=0.5592011412268189, lift=6.463124438123834), OrderedStatistic(items_base=frozenset({'Doctor Strange'}), items_add=frozenset({'Captain America'}), confidence=0.6040061633281972, lift=6.463124438123834)]),
#  RelationRecord(items=frozenset({'Captain America', 'Guardians of the Galaxy'}), support=0.05065991201173177, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Captain America'}), items_add=frozenset({'Guardians of the Galaxy'}), confidence=0.5420827389443652, lift=6.0779710385974335), OrderedStatistic(items_base=frozenset({'Guardians of the Galaxy'}), items_add=frozenset({'Captain America'}), confidence=0.5680119581464873, lift=6.077971038597434)]),
#  RelationRecord(items=frozenset({'Captain America', 'Iron Man'}), support=0.05305959205439275, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Captain America'}), items_add=frozenset({'Iron Man'}), confidence=0.5677603423680457, lift=6.262897541327516), OrderedStatistic(items_base=frozenset({'Iron Man'}), items_add=frozenset({'Captain America'}), confidence=0.5852941176470589, lift=6.262897541327516)]),
#  RelationRecord(items=frozenset({'Spider-Man', 'Captain America'}), support=0.0523930142647647, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Captain America'}), items_add=frozenset({'Spider-Man'}), confidence=0.5606276747503567, lift=6.314216498952591), OrderedStatistic(items_base=frozenset({'Spider-Man'}), items_add=frozenset({'Captain America'}), confidence=0.5900900900900901, lift=6.31421649895259)]),
#  RelationRecord(items=frozenset({'The Avengers', 'Captain America'}), support=0.07079056125849886, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Captain America'}), items_add=frozenset({'The Avengers'}), confidence=0.7574893009985735, lift=5.821646769252356), OrderedStatistic(items_base=frozenset({'The Avengers'}), items_add=frozenset({'Captain America'}), confidence=0.5440573770491803, lift=5.821646769252356)]),
#  RelationRecord(items=frozenset({'Captain America', 'Thor'}), support=0.05225969870683909, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Captain America'}), items_add=frozenset({'Thor'}), confidence=0.5592011412268189, lift=6.307620692244162), OrderedStatistic(items_base=frozenset({'Thor'}), items_add=frozenset({'Captain America'}), confidence=0.5894736842105263, lift=6.307620692244162)]),
#  RelationRecord(items=frozenset({'Coco', 'Finding Nemo'}), support=0.05079322756965738, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Coco'}), items_add=frozenset({'Finding Nemo'}), confidence=0.5870570107858244, lift=6.281761252360155), OrderedStatistic(items_base=frozenset({'Finding Nemo'}), items_add=frozenset({'Coco'}), confidence=0.543509272467903, lift=6.281761252360155)]),
#  RelationRecord(items=frozenset({'Coco', 'Frozen'}), support=0.04986001866417811, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Coco'}), items_add=frozenset({'Frozen'}), confidence=0.576271186440678, lift=6.319605510952522), OrderedStatistic(items_base=frozenset({'Frozen'}), items_add=frozenset({'Coco'}), confidence=0.546783625730994, lift=6.319605510952521)]),
#  RelationRecord(items=frozenset({'Coco', 'Shrek'}), support=0.05025996533795494, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Coco'}), items_add=frozenset({'Shrek'}), confidence=0.5808936825885979, lift=6.455234834217886), OrderedStatistic(items_base=frozenset({'Shrek'}), items_add=frozenset({'Coco'}), confidence=0.5585185185185185, lift=6.455234834217886)]),
#  RelationRecord(items=frozenset({'Coco', 'The Lion King'}), support=0.05332622317024397, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Coco'}), items_add=frozenset({'The Lion King'}), confidence=0.6163328197226503, lift=6.576262419259744), OrderedStatistic(items_base=frozenset({'The Lion King'}), items_add=frozenset({'Coco'}), confidence=0.5689900426742532, lift=6.576262419259744)]),
#  RelationRecord(items=frozenset({'Toy Story', 'Coco'}), support=0.05119317424343421, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Coco'}), items_add=frozenset({'Toy Story'}), confidence=0.5916795069337443, lift=6.189941396806159), OrderedStatistic(items_base=frozenset({'Toy Story'}), items_add=frozenset({'Coco'}), confidence=0.5355648535564854, lift=6.189941396806159)]),
#  RelationRecord(items=frozenset({'Up', 'Coco'}), support=0.05092654312758299, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Coco'}), items_add=frozenset({'Up'}), confidence=0.5885978428351311, lift=6.511906222870675), OrderedStatistic(items_base=frozenset({'Up'}), items_add=frozenset({'Coco'}), confidence=0.5634218289085545, lift=6.5119062228706746)]),
#  RelationRecord(items=frozenset({'Coco', 'WALL-E'}), support=0.04812691641114518, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Coco'}), items_add=frozenset({'WALL-E'}), confidence=0.5562403697996918, lift=6.274224081003742), OrderedStatistic(items_base=frozenset({'WALL-E'}), items_add=frozenset({'Coco'}), confidence=0.5428571428571428, lift=6.274224081003742)]),
#  RelationRecord(items=frozenset({'Deadpool', 'Joker'}), support=0.04986001866417811, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Deadpool'}), items_add=frozenset({'Joker'}), confidence=0.5598802395209581, lift=6.29634434279866), OrderedStatistic(items_base=frozenset({'Joker'}), items_add=frozenset({'Deadpool'}), confidence=0.5607196401799099, lift=6.296344342798659)]),
#  RelationRecord(items=frozenset({'Deadpool', 'Logan'}), support=0.04959338754832689, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Deadpool'}), items_add=frozenset({'Logan'}), confidence=0.5568862275449101, lift=6.300457907713983), OrderedStatistic(items_base=frozenset({'Logan'}), items_add=frozenset({'Deadpool'}), confidence=0.5610859728506786, lift=6.300457907713983)]),
#  RelationRecord(items=frozenset({'Deadpool', 'Man of Steel'}), support=0.04999333422210372, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Deadpool'}), items_add=frozenset({'Man of Steel'}), confidence=0.561377245508982, lift=6.3801374523679915), OrderedStatistic(items_base=frozenset({'Man of Steel'}), items_add=frozenset({'Deadpool'}), confidence=0.5681818181818182, lift=6.380137452367992)]),
#  RelationRecord(items=frozenset({'Deadpool', 'The Dark Knight'}), support=0.0497267031062525, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Deadpool'}), items_add=frozenset({'The Dark Knight'}), confidence=0.5583832335329341, lift=6.242075461595438), OrderedStatistic(items_base=frozenset({'The Dark Knight'}), items_add=frozenset({'Deadpool'}), confidence=0.555886736214605, lift=6.242075461595438)]),
#  RelationRecord(items=frozenset({'Deadpool', 'Venom'}), support=0.04852686308492201, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Deadpool'}), items_add=frozenset({'Venom'}), confidence=0.5449101796407185, lift=6.211810421709772), OrderedStatistic(items_base=frozenset({'Venom'}), items_add=frozenset({'Deadpool'}), confidence=0.5531914893617021, lift=6.211810421709772)]),
#  RelationRecord(items=frozenset({'Deadpool', 'Wonder Woman'}), support=0.04799360085321957, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Deadpool'}), items_add=frozenset({'Wonder Woman'}), confidence=0.5389221556886228, lift=6.416595380667237), OrderedStatistic(items_base=frozenset({'Wonder Woman'}), items_add=frozenset({'Deadpool'}), confidence=0.5714285714285714, lift=6.4165953806672364)]),
#  RelationRecord(items=frozenset({'Doctor Strange', 'Guardians of the Galaxy'}), support=0.0470603919477403, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Doctor Strange'}), items_add=frozenset({'Guardians of the Galaxy'}), confidence=0.5439137134052389, lift=6.098500394996557), OrderedStatistic(items_base=frozenset({'Guardians of the Galaxy'}), items_add=frozenset({'Doctor Strange'}), confidence=0.5276532137518685, lift=6.098500394996557)]),
#  RelationRecord(items=frozenset({'Doctor Strange', 'Iron Man'}), support=0.05039328089588055, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Doctor Strange'}), items_add=frozenset({'Iron Man'}), confidence=0.5824345146379045, lift=6.42476660926312), OrderedStatistic(items_base=frozenset({'Iron Man'}), items_add=frozenset({'Doctor Strange'}), confidence=0.5558823529411764, lift=6.424766609263119)]),
#  RelationRecord(items=frozenset({'Doctor Strange', 'Spider-Man'}), support=0.04679376083188908, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Doctor Strange'}), items_add=frozenset({'Spider-Man'}), confidence=0.5408320493066257, lift=6.091263065839338), OrderedStatistic(items_base=frozenset({'Spider-Man'}), items_add=frozenset({'Doctor Strange'}), confidence=0.5270270270270271, lift=6.091263065839338)]),
#  RelationRecord(items=frozenset({'Doctor Strange', 'The Avengers'}), support=0.06545793894147448, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Doctor Strange'}), items_add=frozenset({'The Avengers'}), confidence=0.7565485362095532, lift=5.814416567733462), OrderedStatistic(items_base=frozenset({'The Avengers'}), items_add=frozenset({'Doctor Strange'}), confidence=0.5030737704918034, lift=5.8144165677334625)]),
#  RelationRecord(items=frozenset({'Doctor Strange', 'Thor'}), support=0.0483935475269964, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Doctor Strange'}), items_add=frozenset({'Thor'}), confidence=0.5593220338983051, lift=6.308984325219829), OrderedStatistic(items_base=frozenset({'Thor'}), items_add=frozenset({'Doctor Strange'}), confidence=0.5458646616541353, lift=6.3089843252198285)]),
#  RelationRecord(items=frozenset({'Fight Club', 'Forrest Gump'}), support=0.054126116517797626, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Fight Club'}), items_add=frozenset({'Forrest Gump'}), confidence=0.5783475783475783, lift=6.033637253386905), OrderedStatistic(items_base=frozenset({'Forrest Gump'}), items_add=frozenset({'Fight Club'}), confidence=0.564673157162726, lift=6.033637253386906)]),
#  RelationRecord(items=frozenset({'Fight Club', 'Gone Girl'}), support=0.05305959205439275, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Fight Club'}), items_add=frozenset({'Gone Girl'}), confidence=0.566951566951567, lift=5.964521323567608), OrderedStatistic(items_base=frozenset({'Gone Girl'}), items_add=frozenset({'Fight Club'}), confidence=0.5582047685834503, lift=5.964521323567607)]),
#  RelationRecord(items=frozenset({'Fight Club', 'Pulp Fiction'}), support=0.05519264098120251, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Fight Club'}), items_add=frozenset({'Pulp Fiction'}), confidence=0.5897435897435898, lift=6.15252665739453), OrderedStatistic(items_base=frozenset({'Pulp Fiction'}), items_add=frozenset({'Fight Club'}), confidence=0.5757997218358832, lift=6.15252665739453)]),
#  RelationRecord(items=frozenset({'Fight Club', 'The Godfather'}), support=0.054259432075723237, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Fight Club'}), items_add=frozenset({'The Godfather'}), confidence=0.5797720797720798, lift=6.159873045850383), OrderedStatistic(items_base=frozenset({'The Godfather'}), items_add=frozenset({'Fight Club'}), confidence=0.5764872521246459, lift=6.159873045850383)]),
#  RelationRecord(items=frozenset({'Fight Club', 'The Social Network'}), support=0.053992800959872016, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Fight Club'}), items_add=frozenset({'The Social Network'}), confidence=0.5769230769230769, lift=6.373343151693667), OrderedStatistic(items_base=frozenset({'The Social Network'}), items_add=frozenset({'Fight Club'}), confidence=0.5964653902798233, lift=6.373343151693667)]),
#  RelationRecord(items=frozenset({'Fight Club', 'Whiplash'}), support=0.056525796560458606, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Fight Club'}), items_add=frozenset({'Whiplash'}), confidence=0.603988603988604, lift=6.18923294879579), OrderedStatistic(items_base=frozenset({'Whiplash'}), items_add=frozenset({'Fight Club'}), confidence=0.5792349726775956, lift=6.18923294879579)]),
#  RelationRecord(items=frozenset({'Frozen', 'Finding Nemo'}), support=0.051459805359285425, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Finding Nemo'}), items_add=frozenset({'Frozen'}), confidence=0.550641940085592, lift=6.038545603190095), OrderedStatistic(items_base=frozenset({'Frozen'}), items_add=frozenset({'Finding Nemo'}), confidence=0.5643274853801169, lift=6.038545603190096)]),
#  RelationRecord(items=frozenset({'Shrek', 'Finding Nemo'}), support=0.051859752033062256, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Finding Nemo'}), items_add=frozenset({'Shrek'}), confidence=0.5549215406562055, lift=6.166617002166219), OrderedStatistic(items_base=frozenset({'Shrek'}), items_add=frozenset({'Finding Nemo'}), confidence=0.5762962962962963, lift=6.166617002166218)]),
#  RelationRecord(items=frozenset({'The Lion King', 'Finding Nemo'}), support=0.05452606319157446, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Finding Nemo'}), items_add=frozenset({'The Lion King'}), confidence=0.5834522111269616, lift=6.225426793262217), OrderedStatistic(items_base=frozenset({'The Lion King'}), items_add=frozenset({'Finding Nemo'}), confidence=0.5817923186344239, lift=6.225426793262217)]),
#  RelationRecord(items=frozenset({'Toy Story', 'Finding Nemo'}), support=0.05452606319157446, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Finding Nemo'}), items_add=frozenset({'Toy Story'}), confidence=0.5834522111269616, lift=6.103870342626693), OrderedStatistic(items_base=frozenset({'Toy Story'}), items_add=frozenset({'Finding Nemo'}), confidence=0.5704323570432357, lift=6.103870342626692)]),
#  RelationRecord(items=frozenset({'Up', 'Finding Nemo'}), support=0.05305959205439275, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Finding Nemo'}), items_add=frozenset({'Up'}), confidence=0.5677603423680457, lift=6.281372165343232), OrderedStatistic(items_base=frozenset({'Up'}), items_add=frozenset({'Finding Nemo'}), confidence=0.5870206489675516, lift=6.281372165343231)]),
#  RelationRecord(items=frozenset({'WALL-E', 'Finding Nemo'}), support=0.051859752033062256, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Finding Nemo'}), items_add=frozenset({'WALL-E'}), confidence=0.5549215406562055, lift=6.259348084905559), OrderedStatistic(items_base=frozenset({'WALL-E'}), items_add=frozenset({'Finding Nemo'}), confidence=0.5849624060150376, lift=6.259348084905559)]),
#  RelationRecord(items=frozenset({'Gone Girl', 'Forrest Gump'}), support=0.05665911211838422, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Forrest Gump'}), items_add=frozenset({'Gone Girl'}), confidence=0.5910987482614742, lift=6.218557799031302), OrderedStatistic(items_base=frozenset({'Gone Girl'}), items_add=frozenset({'Forrest Gump'}), confidence=0.5960729312762973, lift=6.218557799031302)]),
#  RelationRecord(items=frozenset({'Pulp Fiction', 'Forrest Gump'}), support=0.05732568990801226, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Forrest Gump'}), items_add=frozenset({'Pulp Fiction'}), confidence=0.5980528511821974, lift=6.239213402945289), OrderedStatistic(items_base=frozenset({'Pulp Fiction'}), items_add=frozenset({'Forrest Gump'}), confidence=0.5980528511821974, lift=6.239213402945289)]),
#  RelationRecord(items=frozenset({'The Godfather', 'Forrest Gump'}), support=0.056392481002532996, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Forrest Gump'}), items_add=frozenset({'The Godfather'}), confidence=0.588317107093185, lift=6.250660935277592), OrderedStatistic(items_base=frozenset({'The Godfather'}), items_add=frozenset({'Forrest Gump'}), confidence=0.5991501416430595, lift=6.250660935277592)]),
#  RelationRecord(items=frozenset({'Forrest Gump', 'The Social Network'}), support=0.056525796560458606, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Forrest Gump'}), items_add=frozenset({'The Social Network'}), confidence=0.5897079276773296, lift=6.51457903609374), OrderedStatistic(items_base=frozenset({'The Social Network'}), items_add=frozenset({'Forrest Gump'}), confidence=0.6244477172312224, lift=6.51457903609374)]),
#  RelationRecord(items=frozenset({'Whiplash', 'Forrest Gump'}), support=0.057992267697640314, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Forrest Gump'}), items_add=frozenset({'Whiplash'}), confidence=0.6050069541029207, lift=6.199668255090175), OrderedStatistic(items_base=frozenset({'Whiplash'}), items_add=frozenset({'Forrest Gump'}), confidence=0.5942622950819672, lift=6.199668255090175)]),
#  RelationRecord(items=frozenset({'Shrek', 'Frozen'}), support=0.05252632982269031, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Frozen'}), items_add=frozenset({'Shrek'}), confidence=0.5760233918128654, lift=6.401113277019709), OrderedStatistic(items_base=frozenset({'Shrek'}), items_add=frozenset({'Frozen'}), confidence=0.5837037037037037, lift=6.40111327701971)]),
#  RelationRecord(items=frozenset({'The Lion King', 'Frozen'}), support=0.051726436475136646, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Frozen'}), items_add=frozenset({'The Lion King'}), confidence=0.567251461988304, lift=6.052565030404365), OrderedStatistic(items_base=frozenset({'The Lion King'}), items_add=frozenset({'Frozen'}), confidence=0.5519203413940256, lift=6.052565030404365)]),
#  RelationRecord(items=frozenset({'Toy Story', 'Frozen'}), support=0.05519264098120251, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Frozen'}), items_add=frozenset({'Toy Story'}), confidence=0.6052631578947368, lift=6.3320487410996105), OrderedStatistic(items_base=frozenset({'Toy Story'}), items_add=frozenset({'Frozen'}), confidence=0.5774058577405858, lift=6.332048741099611)]),
#  RelationRecord(items=frozenset({'Up', 'Frozen'}), support=0.05132648980135982, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Frozen'}), items_add=frozenset({'Up'}), confidence=0.5628654970760234, lift=6.2272184270903415), OrderedStatistic(items_base=frozenset({'Up'}), items_add=frozenset({'Frozen'}), confidence=0.5678466076696165, lift=6.227218427090341)]),
#  RelationRecord(items=frozenset({'WALL-E', 'Frozen'}), support=0.051859752033062256, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Frozen'}), items_add=frozenset({'WALL-E'}), confidence=0.5687134502923976, lift=6.414916677659059), OrderedStatistic(items_base=frozenset({'WALL-E'}), items_add=frozenset({'Frozen'}), confidence=0.5849624060150376, lift=6.414916677659059)]),
#  RelationRecord(items=frozenset({'Gone Girl', 'Pulp Fiction'}), support=0.0578589521397147, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Gone Girl'}), items_add=frozenset({'Pulp Fiction'}), confidence=0.6086956521739131, lift=6.35024490536373), OrderedStatistic(items_base=frozenset({'Pulp Fiction'}), items_add=frozenset({'Gone Girl'}), confidence=0.6036161335187761, lift=6.35024490536373)]),
#  RelationRecord(items=frozenset({'Gone Girl', 'The Godfather'}), support=0.05225969870683909, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Gone Girl'}), items_add=frozenset({'The Godfather'}), confidence=0.5497896213183731, lift=5.841320041797615), OrderedStatistic(items_base=frozenset({'The Godfather'}), items_add=frozenset({'Gone Girl'}), confidence=0.5552407932011331, lift=5.841320041797615)]),
#  RelationRecord(items=frozenset({'Gone Girl', 'The Social Network'}), support=0.05452606319157446, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Gone Girl'}), items_add=frozenset({'The Social Network'}), confidence=0.573632538569425, lift=6.336992152885504), OrderedStatistic(items_base=frozenset({'The Social Network'}), items_add=frozenset({'Gone Girl'}), confidence=0.6023564064801178, lift=6.336992152885503)]),
#  RelationRecord(items=frozenset({'Gone Girl', 'Whiplash'}), support=0.0578589521397147, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Gone Girl'}), items_add=frozenset({'Whiplash'}), confidence=0.6086956521739131, lift=6.237467331907816), OrderedStatistic(items_base=frozenset({'Whiplash'}), items_add=frozenset({'Gone Girl'}), confidence=0.592896174863388, lift=6.237467331907816)]),
#  RelationRecord(items=frozenset({'Guardians of the Galaxy', 'Iron Man'}), support=0.04879349420077323, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Guardians of the Galaxy'}), items_add=frozenset({'Iron Man'}), confidence=0.547085201793722, lift=6.03483249802163), OrderedStatistic(items_base=frozenset({'Iron Man'}), items_add=frozenset({'Guardians of the Galaxy'}), confidence=0.538235294117647, lift=6.034832498021629)]),
#  RelationRecord(items=frozenset({'Spider-Man', 'Guardians of the Galaxy'}), support=0.05025996533795494, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Guardians of the Galaxy'}), items_add=frozenset({'Spider-Man'}), confidence=0.5635276532137519, lift=6.346878268402932), OrderedStatistic(items_base=frozenset({'Spider-Man'}), items_add=frozenset({'Guardians of the Galaxy'}), confidence=0.566066066066066, lift=6.346878268402931)]),
#  RelationRecord(items=frozenset({'The Avengers', 'Guardians of the Galaxy'}), support=0.06639114784695374, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Guardians of the Galaxy'}), items_add=frozenset({'The Avengers'}), confidence=0.7443946188340806, lift=5.721008233477909), OrderedStatistic(items_base=frozenset({'The Avengers'}), items_add=frozenset({'Guardians of the Galaxy'}), confidence=0.5102459016393442, lift=5.721008233477908)]),
#  RelationRecord(items=frozenset({'Guardians of the Galaxy', 'Thor'}), support=0.04892680975869884, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Guardians of the Galaxy'}), items_add=frozenset({'Thor'}), confidence=0.5485799701046338, lift=6.187817076323094), OrderedStatistic(items_base=frozenset({'Thor'}), items_add=frozenset({'Guardians of the Galaxy'}), confidence=0.5518796992481203, lift=6.187817076323094)]),
#  RelationRecord(items=frozenset({'Inception', 'Interstellar'}), support=0.055992534328756165, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Inception'}), items_add=frozenset({'Interstellar'}), confidence=0.6043165467625898, lift=6.175719914531589), OrderedStatistic(items_base=frozenset({'Interstellar'}), items_add=frozenset({'Inception'}), confidence=0.5722070844686649, lift=6.17571991453159)]),
#  RelationRecord(items=frozenset({'Inception', 'Jurassic Park'}), support=0.056525796560458606, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Inception'}), items_add=frozenset({'Jurassic Park'}), confidence=0.6100719424460431, lift=6.45437184807866), OrderedStatistic(items_base=frozenset({'Jurassic Park'}), items_add=frozenset({'Inception'}), confidence=0.5980253878702398, lift=6.45437184807866)]),
#  RelationRecord(items=frozenset({'Star Wars', 'Inception'}), support=0.055859218770830554, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Inception'}), items_add=frozenset({'Star Wars'}), confidence=0.6028776978417266, lift=6.46026515930113), OrderedStatistic(items_base=frozenset({'Star Wars'}), items_add=frozenset({'Inception'}), confidence=0.5985714285714285, lift=6.460265159301129)]),
#  RelationRecord(items=frozenset({'Inception', 'The Hunger Games'}), support=0.05772563658178909, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Inception'}), items_add=frozenset({'The Hunger Games'}), confidence=0.6230215827338129, lift=6.676121274409044), OrderedStatistic(items_base=frozenset({'The Hunger Games'}), items_add=frozenset({'Inception'}), confidence=0.6185714285714285, lift=6.676121274409043)]),
#  RelationRecord(items=frozenset({'Inception', 'The Matrix'}), support=0.060658578856152515, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Inception'}), items_add=frozenset({'The Matrix'}), confidence=0.6546762589928058, lift=6.690363240742556), OrderedStatistic(items_base=frozenset({'The Matrix'}), items_add=frozenset({'Inception'}), confidence=0.6198910081743869, lift=6.690363240742555)]),
#  RelationRecord(items=frozenset({'Interstellar', 'Jurassic Park'}), support=0.05932542327689641, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Interstellar'}), items_add=frozenset({'Jurassic Park'}), confidence=0.606267029972752, lift=6.41411705476109), OrderedStatistic(items_base=frozenset({'Jurassic Park'}), items_add=frozenset({'Interstellar'}), confidence=0.6276445698166432, lift=6.414117054761091)]),
#  RelationRecord(items=frozenset({'Star Wars', 'Interstellar'}), support=0.05519264098120251, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Interstellar'}), items_add=frozenset({'Star Wars'}), confidence=0.5640326975476839, lift=6.044013234721682), OrderedStatistic(items_base=frozenset({'Star Wars'}), items_add=frozenset({'Interstellar'}), confidence=0.5914285714285714, lift=6.044013234721681)]),
#  RelationRecord(items=frozenset({'Interstellar', 'The Hunger Games'}), support=0.05945873883482202, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Interstellar'}), items_add=frozenset({'The Hunger Games'}), confidence=0.6076294277929155, lift=6.511183339820942), OrderedStatistic(items_base=frozenset({'The Hunger Games'}), items_add=frozenset({'Interstellar'}), confidence=0.6371428571428571, lift=6.511183339820942)]),
#  RelationRecord(items=frozenset({'Interstellar', 'The Matrix'}), support=0.05945873883482202, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Interstellar'}), items_add=frozenset({'The Matrix'}), confidence=0.6076294277929155, lift=6.209575392199808), OrderedStatistic(items_base=frozenset({'The Matrix'}), items_add=frozenset({'Interstellar'}), confidence=0.6076294277929155, lift=6.209575392199808)]),
#  RelationRecord(items=frozenset({'Spider-Man', 'Iron Man'}), support=0.05092654312758299, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Iron Man'}), items_add=frozenset({'Spider-Man'}), confidence=0.5617647058823529, lift=6.32702261084614), OrderedStatistic(items_base=frozenset({'Spider-Man'}), items_add=frozenset({'Iron Man'}), confidence=0.5735735735735736, lift=6.32702261084614)]),
#  RelationRecord(items=frozenset({'The Avengers', 'Iron Man'}), support=0.067324356752433, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Iron Man'}), items_add=frozenset({'The Avengers'}), confidence=0.7426470588235293, lift=5.707577446962391), OrderedStatistic(items_base=frozenset({'The Avengers'}), items_add=frozenset({'Iron Man'}), confidence=0.5174180327868853, lift=5.707577446962391)]),
#  RelationRecord(items=frozenset({'Iron Man', 'Thor'}), support=0.04986001866417811, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Iron Man'}), items_add=frozenset({'Thor'}), confidence=0.5499999999999999, lift=6.203834586466164), OrderedStatistic(items_base=frozenset({'Thor'}), items_add=frozenset({'Iron Man'}), confidence=0.5624060150375939, lift=6.203834586466164)]),
#  RelationRecord(items=frozenset({'Mad Max: Fury Road', 'John Wick'}), support=0.0753232902279696, ordered_statistics=[OrderedStatistic(items_base=frozenset({'John Wick'}), items_add=frozenset({'Mad Max: Fury Road'}), confidence=0.6615925058548009, lift=5.790671396052347), OrderedStatistic(items_base=frozenset({'Mad Max: Fury Road'}), items_add=frozenset({'John Wick'}), confidence=0.6592765460910152, lift=5.790671396052347)]),
#  RelationRecord(items=frozenset({'Mission: Impossible', 'John Wick'}), support=0.07372350353286229, ordered_statistics=[OrderedStatistic(items_base=frozenset({'John Wick'}), items_add=frozenset({'Mission: Impossible'}), confidence=0.6475409836065574, lift=5.674304810785967), OrderedStatistic(items_base=frozenset({'Mission: Impossible'}), items_add=frozenset({'John Wick'}), confidence=0.6460280373831776, lift=5.674304810785966)]),
#  RelationRecord(items=frozenset({'Joker', 'Logan'}), support=0.05052659645380616, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Joker'}), items_add=frozenset({'Logan'}), confidence=0.5682158920539729, lift=6.428638621865537), OrderedStatistic(items_base=frozenset({'Logan'}), items_add=frozenset({'Joker'}), confidence=0.5716440422322775, lift=6.428638621865537)]),
#  RelationRecord(items=frozenset({'Joker', 'Man of Steel'}), support=0.05079322756965738, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Joker'}), items_add=frozenset({'Man of Steel'}), confidence=0.5712143928035982, lift=6.491938121848167), OrderedStatistic(items_base=frozenset({'Man of Steel'}), items_add=frozenset({'Joker'}), confidence=0.5772727272727273, lift=6.491938121848166)]),
#  RelationRecord(items=frozenset({'Joker', 'The Dark Knight'}), support=0.05292627649646714, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Joker'}), items_add=frozenset({'The Dark Knight'}), confidence=0.5952023988005997, lift=6.653670929066019), OrderedStatistic(items_base=frozenset({'The Dark Knight'}), items_add=frozenset({'Joker'}), confidence=0.5916542473919524, lift=6.653670929066019)]),
#  RelationRecord(items=frozenset({'Joker', 'Venom'}), support=0.05012664978002933, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Joker'}), items_add=frozenset({'Venom'}), confidence=0.5637181409295352, lift=6.426215463696723), OrderedStatistic(items_base=frozenset({'Venom'}), items_add=frozenset({'Joker'}), confidence=0.5714285714285714, lift=6.426215463696722)]),
#  RelationRecord(items=frozenset({'Joker', 'Wonder Woman'}), support=0.04799360085321957, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Joker'}), items_add=frozenset({'Wonder Woman'}), confidence=0.5397301349325336, lift=6.426215463696722), OrderedStatistic(items_base=frozenset({'Wonder Woman'}), items_add=frozenset({'Joker'}), confidence=0.5714285714285714, lift=6.426215463696722)]),
#  RelationRecord(items=frozenset({'Star Wars', 'Jurassic Park'}), support=0.056525796560458606, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Jurassic Park'}), items_add=frozenset({'Star Wars'}), confidence=0.5980253878702398, lift=6.408269192020955), OrderedStatistic(items_base=frozenset({'Star Wars'}), items_add=frozenset({'Jurassic Park'}), confidence=0.6057142857142858, lift=6.408269192020955)]),
#  RelationRecord(items=frozenset({'Jurassic Park', 'The Hunger Games'}), support=0.05719237435008666, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Jurassic Park'}), items_add=frozenset({'The Hunger Games'}), confidence=0.6050775740479549, lift=6.483838404191014), OrderedStatistic(items_base=frozenset({'The Hunger Games'}), items_add=frozenset({'Jurassic Park'}), confidence=0.6128571428571429, lift=6.4838384041910135)]),
#  RelationRecord(items=frozenset({'Jurassic Park', 'The Matrix'}), support=0.05959205439274763, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Jurassic Park'}), items_add=frozenset({'The Matrix'}), confidence=0.6304654442877292, lift=6.442944547142039), OrderedStatistic(items_base=frozenset({'The Matrix'}), items_add=frozenset({'Jurassic Park'}), confidence=0.608991825613079, lift=6.442944547142039)]),
#  RelationRecord(items=frozenset({'Titanic', 'La La Land'}), support=0.07105719237435008, ordered_statistics=[OrderedStatistic(items_base=frozenset({'La La Land'}), items_add=frozenset({'Titanic'}), confidence=0.6063708759954494, lift=5.2521800702561965), OrderedStatistic(items_base=frozenset({'Titanic'}), items_add=frozenset({'La La Land'}), confidence=0.6154734411085451, lift=5.2521800702561965)]),
#  RelationRecord(items=frozenset({'Twilight', 'La La Land'}), support=0.07545660578589522, ordered_statistics=[OrderedStatistic(items_base=frozenset({'La La Land'}), items_add=frozenset({'Twilight'}), confidence=0.6439135381114904, lift=5.210351078073668), OrderedStatistic(items_base=frozenset({'Twilight'}), items_add=frozenset({'La La Land'}), confidence=0.6105717367853291, lift=5.210351078073667)]),
#  RelationRecord(items=frozenset({'Logan', 'Man of Steel'}), support=0.0497267031062525, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Logan'}), items_add=frozenset({'Man of Steel'}), confidence=0.5625942684766214, lift=6.393969102792632), OrderedStatistic(items_base=frozenset({'Man of Steel'}), items_add=frozenset({'Logan'}), confidence=0.5651515151515152, lift=6.393969102792632)]),
#  RelationRecord(items=frozenset({'Logan', 'The Dark Knight'}), support=0.05039328089588055, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Logan'}), items_add=frozenset({'The Dark Knight'}), confidence=0.5701357466063348, lift=6.37345489611642), OrderedStatistic(items_base=frozenset({'The Dark Knight'}), items_add=frozenset({'Logan'}), confidence=0.5633383010432191, lift=6.37345489611642)]),
# ...
#  RelationRecord(items=frozenset({'Mad Max: Fury Road', 'The Godfather', 'The Social Network'}), support=0.0041327822956939075, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Mad Max: Fury Road', 'The Godfather'}), items_add=frozenset({'The Social Network'}), confidence=0.7380952380952381, lift=8.153832667087455), OrderedStatistic(items_base=frozenset({'Mad Max: Fury Road', 'The Social Network'}), items_add=frozenset({'The Godfather'}), confidence=0.6739130434782609, lift=7.1600874491932505)]),
#  RelationRecord(items=frozenset({'Mad Max: Fury Road', 'Whiplash', 'The Godfather'}), support=0.004666044527396347, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Mad Max: Fury Road', 'The Godfather'}), items_add=frozenset({'Whiplash'}), confidence=0.8333333333333334, lift=8.539389799635702), OrderedStatistic(items_base=frozenset({'Mad Max: Fury Road', 'Whiplash'}), items_add=frozenset({'The Godfather'}), confidence=0.7777777777777778, lift=8.26361347182877)]),
#  RelationRecord(items=frozenset({'Mad Max: Fury Road', 'The Hunger Games', 'The Matrix'}), support=0.006265831222503666, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Mad Max: Fury Road', 'The Hunger Games'}), items_add=frozenset({'The Matrix'}), confidence=0.8545454545454545, lift=8.732895714639582), OrderedStatistic(items_base=frozenset({'Mad Max: Fury Road', 'The Matrix'}), items_add=frozenset({'The Hunger Games'}), confidence=0.7460317460317459, lift=7.994263038548752)]),
#  RelationRecord(items=frozenset({'Mad Max: Fury Road', 'Toy Story', 'The Lion King'}), support=0.003999466737768298, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Mad Max: Fury Road', 'The Lion King'}), items_add=frozenset({'Toy Story'}), confidence=0.6818181818181819, lift=7.132940281475847), OrderedStatistic(items_base=frozenset({'Mad Max: Fury Road', 'Toy Story'}), items_add=frozenset({'The Lion King'}), confidence=0.6818181818181819, lift=7.274990301306092)]),
#  RelationRecord(items=frozenset({'Mad Max: Fury Road', 'Up', 'The Lion King'}), support=0.003199573390214638, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Mad Max: Fury Road', 'The Lion King'}), items_add=frozenset({'Up'}), confidence=0.5454545454545454, lift=6.034593724859211), OrderedStatistic(items_base=frozenset({'Mad Max: Fury Road', 'Up'}), items_add=frozenset({'The Lion King'}), confidence=0.6153846153846154, lift=6.566145092460883)]),
#  RelationRecord(items=frozenset({'Mad Max: Fury Road', 'The Lion King', 'WALL-E'}), support=0.0035995200639914677, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Mad Max: Fury Road', 'The Lion King'}), items_add=frozenset({'WALL-E'}), confidence=0.6136363636363636, lift=6.921633629528366), OrderedStatistic(items_base=frozenset({'Mad Max: Fury Road', 'WALL-E'}), items_add=frozenset({'The Lion King'}), confidence=0.6136363636363636, lift=6.547491271175482)]),
#  RelationRecord(items=frozenset({'Mad Max: Fury Road', 'Whiplash', 'The Social Network'}), support=0.004266097853619517, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Mad Max: Fury Road', 'The Social Network'}), items_add=frozenset({'Whiplash'}), confidence=0.6956521739130433, lift=7.128534093608931), OrderedStatistic(items_base=frozenset({'Mad Max: Fury Road', 'Whiplash'}), items_add=frozenset({'The Social Network'}), confidence=0.711111111111111, lift=7.855735558828342)]),
#  RelationRecord(items=frozenset({'Mad Max: Fury Road', 'Titanic', 'Twilight'}), support=0.005332622317024397, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Mad Max: Fury Road', 'Titanic'}), items_add=frozenset({'Twilight'}), confidence=0.7272727272727273, lift=5.884868098460331), OrderedStatistic(items_base=frozenset({'Mad Max: Fury Road', 'Twilight'}), items_add=frozenset({'Titanic'}), confidence=0.6557377049180328, lift=5.679778896755386)]),
#  RelationRecord(items=frozenset({'Mad Max: Fury Road', 'Up', 'Toy Story'}), support=0.0034662045060658577, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Mad Max: Fury Road', 'Toy Story'}), items_add=frozenset({'Up'}), confidence=0.5909090909090908, lift=6.537476535264145), OrderedStatistic(items_base=frozenset({'Mad Max: Fury Road', 'Up'}), items_add=frozenset({'Toy Story'}), confidence=0.6666666666666666, lift=6.974430497443049)]),
#  RelationRecord(items=frozenset({'Mad Max: Fury Road', 'Toy Story', 'WALL-E'}), support=0.0037328356219170776, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Mad Max: Fury Road', 'Toy Story'}), items_add=frozenset({'WALL-E'}), confidence=0.6363636363636364, lift=7.1779904306220095), OrderedStatistic(items_base=frozenset({'Mad Max: Fury Road', 'WALL-E'}), items_add=frozenset({'Toy Story'}), confidence=0.6363636363636364, lift=6.657410929377456)]),
#  RelationRecord(items=frozenset({'Titanic', 'Man of Steel', 'The Dark Knight'}), support=0.0034662045060658577, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Titanic', 'Man of Steel'}), items_add=frozenset({'The Dark Knight'}), confidence=0.65, lift=7.2662444113263795), OrderedStatistic(items_base=frozenset({'Titanic', 'The Dark Knight'}), items_add=frozenset({'Man of Steel'}), confidence=0.6046511627906976, lift=6.871952078928823)]),
#  RelationRecord(items=frozenset({'Twilight', 'Man of Steel', 'The Dark Knight'}), support=0.0037328356219170776, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Twilight', 'Man of Steel'}), items_add=frozenset({'The Dark Knight'}), confidence=0.7179487179487178, lift=8.025832091405862), OrderedStatistic(items_base=frozenset({'Twilight', 'The Dark Knight'}), items_add=frozenset({'Man of Steel'}), confidence=0.6363636363636364, lift=7.23236914600551)]),
#  RelationRecord(items=frozenset({'Man of Steel', 'Venom', 'The Dark Knight'}), support=0.03172910278629516, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Man of Steel'}), items_add=frozenset({'Venom', 'The Dark Knight'}), confidence=0.36060606060606065, lift=6.9894213452353), OrderedStatistic(items_base=frozenset({'The Dark Knight'}), items_add=frozenset({'Man of Steel', 'Venom'}), confidence=0.3546944858420269, lift=7.289214625482312), OrderedStatistic(items_base=frozenset({'Venom'}), items_add=frozenset({'Man of Steel', 'The Dark Knight'}), confidence=0.36170212765957455, lift=7.235007092198583), OrderedStatistic(items_base=frozenset({'Man of Steel', 'The Dark Knight'}), items_add=frozenset({'Venom'}), confidence=0.6346666666666667, lift=7.2350070921985825), OrderedStatistic(items_base=frozenset({'Man of Steel', 'Venom'}), items_add=frozenset({'The Dark Knight'}), confidence=0.652054794520548, lift=7.289214625482312), OrderedStatistic(items_base=frozenset({'Venom', 'The Dark Knight'}), items_add=frozenset({'Man of Steel'}), confidence=0.6149870801033592, lift=6.9894213452353)]),
#  RelationRecord(items=frozenset({'Man of Steel', 'Wonder Woman', 'The Dark Knight'}), support=0.03079589388081589, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Man of Steel'}), items_add=frozenset({'Wonder Woman', 'The Dark Knight'}), confidence=0.35000000000000003, lift=7.312952646239555), OrderedStatistic(items_base=frozenset({'The Dark Knight'}), items_add=frozenset({'Man of Steel', 'Wonder Woman'}), confidence=0.3442622950819672, lift=7.25368391969055), OrderedStatistic(items_base=frozenset({'Wonder Woman'}), items_add=frozenset({'Man of Steel', 'The Dark Knight'}), confidence=0.3666666666666667, lift=7.334311111111112), OrderedStatistic(items_base=frozenset({'Man of Steel', 'The Dark Knight'}), items_add=frozenset({'Wonder Woman'}), confidence=0.616, lift=7.334311111111112), OrderedStatistic(items_base=frozenset({'Man of Steel', 'Wonder Woman'}), items_add=frozenset({'The Dark Knight'}), confidence=0.648876404494382, lift=7.253683919690551), OrderedStatistic(items_base=frozenset({'Wonder Woman', 'The Dark Knight'}), items_add=frozenset({'Man of Steel'}), confidence=0.6434540389972145, lift=7.312952646239555)]),
#  RelationRecord(items=frozenset({'Titanic', 'Twilight', 'Man of Steel'}), support=0.0035995200639914677, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Titanic', 'Man of Steel'}), items_add=frozenset({'Twilight'}), confidence=0.6749999999999999, lift=5.461893203883494), OrderedStatistic(items_base=frozenset({'Twilight', 'Man of Steel'}), items_add=frozenset({'Titanic'}), confidence=0.6923076923076922, lift=5.996535796766743)]),
#  RelationRecord(items=frozenset({'Titanic', 'Man of Steel', 'Venom'}), support=0.003199573390214638, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Titanic', 'Man of Steel'}), items_add=frozenset({'Venom'}), confidence=0.6, lift=6.839817629179332), OrderedStatistic(items_base=frozenset({'Titanic', 'Venom'}), items_add=frozenset({'Man of Steel'}), confidence=0.5714285714285714, lift=6.494372294372295)]),
#  RelationRecord(items=frozenset({'Wonder Woman', 'Man of Steel', 'Venom'}), support=0.03079589388081589, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Man of Steel'}), items_add=frozenset({'Venom', 'Wonder Woman'}), confidence=0.35000000000000003, lift=7.312952646239555), OrderedStatistic(items_base=frozenset({'Venom'}), items_add=frozenset({'Man of Steel', 'Wonder Woman'}), confidence=0.35106382978723405, lift=7.3969937843652875), OrderedStatistic(items_base=frozenset({'Wonder Woman'}), items_add=frozenset({'Man of Steel', 'Venom'}), confidence=0.3666666666666667, lift=7.535251141552512), OrderedStatistic(items_base=frozenset({'Man of Steel', 'Venom'}), items_add=frozenset({'Wonder Woman'}), confidence=0.6328767123287671, lift=7.535251141552512), OrderedStatistic(items_base=frozenset({'Man of Steel', 'Wonder Woman'}), items_add=frozenset({'Venom'}), confidence=0.648876404494382, lift=7.396993784365288), OrderedStatistic(items_base=frozenset({'Venom', 'Wonder Woman'}), items_add=frozenset({'Man of Steel'}), confidence=0.6434540389972145, lift=7.312952646239555)]),
#  RelationRecord(items=frozenset({'Pulp Fiction', 'The Godfather', 'Mission: Impossible'}), support=0.004399413411545127, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Pulp Fiction', 'Mission: Impossible'}), items_add=frozenset({'The Godfather'}), confidence=0.8461538461538461, lift=8.990084985835693), OrderedStatistic(items_base=frozenset({'The Godfather', 'Mission: Impossible'}), items_add=frozenset({'Pulp Fiction'}), confidence=0.7674418604651163, lift=8.006371898955267)]),
#  RelationRecord(items=frozenset({'The Social Network', 'Pulp Fiction', 'Mission: Impossible'}), support=0.0037328356219170776, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Pulp Fiction', 'Mission: Impossible'}), items_add=frozenset({'The Social Network'}), confidence=0.7179487179487178, lift=7.93127147766323), OrderedStatistic(items_base=frozenset({'The Social Network', 'Mission: Impossible'}), items_add=frozenset({'Pulp Fiction'}), confidence=0.7567567567567567, lift=7.894899071533285)]),
#  RelationRecord(items=frozenset({'Whiplash', 'Pulp Fiction', 'Mission: Impossible'}), support=0.0035995200639914677, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Pulp Fiction', 'Mission: Impossible'}), items_add=frozenset({'Whiplash'}), confidence=0.6923076923076922, lift=7.094262295081966), OrderedStatistic(items_base=frozenset({'Whiplash', 'Mission: Impossible'}), items_add=frozenset({'Pulp Fiction'}), confidence=0.6923076923076922, lift=7.222531293463142)]),
#  RelationRecord(items=frozenset({'The Lion King', 'Mission: Impossible', 'Shrek'}), support=0.004666044527396347, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Mission: Impossible', 'Shrek'}), items_add=frozenset({'The Lion King'}), confidence=0.7142857142857143, lift=7.621418410892096), OrderedStatistic(items_base=frozenset({'The Lion King', 'Mission: Impossible'}), items_add=frozenset({'Shrek'}), confidence=0.6862745098039216, lift=7.626289034132172)]),
#  RelationRecord(items=frozenset({'Toy Story', 'Mission: Impossible', 'Shrek'}), support=0.004266097853619517, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Mission: Impossible', 'Shrek'}), items_add=frozenset({'Toy Story'}), confidence=0.6530612244897959, lift=6.832095181168701), OrderedStatistic(items_base=frozenset({'Toy Story', 'Mission: Impossible'}), items_add=frozenset({'Shrek'}), confidence=0.6808510638297872, lift=7.56602048857368)]),
#  RelationRecord(items=frozenset({'Up', 'Mission: Impossible', 'Shrek'}), support=0.0037328356219170776, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Mission: Impossible', 'Shrek'}), items_add=frozenset({'Up'}), confidence=0.5714285714285714, lift=6.3219553308048875), OrderedStatistic(items_base=frozenset({'Up', 'Mission: Impossible'}), items_add=frozenset({'Shrek'}), confidence=0.7368421052631579, lift=8.1882261208577)]),
#  RelationRecord(items=frozenset({'WALL-E', 'Mission: Impossible', 'Shrek'}), support=0.004399413411545127, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Mission: Impossible', 'Shrek'}), items_add=frozenset({'WALL-E'}), confidence=0.673469387755102, lift=7.596532146693263), OrderedStatistic(items_base=frozenset({'WALL-E', 'Mission: Impossible'}), items_add=frozenset({'Shrek'}), confidence=0.7333333333333334, lift=8.149234567901235)]),
#  RelationRecord(items=frozenset({'Star Wars', 'The Hunger Games', 'Mission: Impossible'}), support=0.005999200106652446, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Star Wars', 'Mission: Impossible'}), items_add=frozenset({'The Hunger Games'}), confidence=0.8035714285714286, lift=8.610841836734695), OrderedStatistic(items_base=frozenset({'The Hunger Games', 'Mission: Impossible'}), items_add=frozenset({'Star Wars'}), confidence=0.8181818181818181, lift=8.767402597402597)]),
#  RelationRecord(items=frozenset({'Star Wars', 'Mission: Impossible', 'The Matrix'}), support=0.005732568990801226, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Star Wars', 'Mission: Impossible'}), items_add=frozenset({'The Matrix'}), confidence=0.7678571428571428, lift=7.8469978590891385), OrderedStatistic(items_base=frozenset({'Mission: Impossible', 'The Matrix'}), items_add=frozenset({'Star Wars'}), confidence=0.7166666666666666, lift=7.679595238095237)]),
#  RelationRecord(items=frozenset({'The Social Network', 'The Godfather', 'Mission: Impossible'}), support=0.0041327822956939075, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Godfather', 'Mission: Impossible'}), items_add=frozenset({'The Social Network'}), confidence=0.7209302325581396, lift=7.964208651573792), OrderedStatistic(items_base=frozenset({'The Social Network', 'Mission: Impossible'}), items_add=frozenset({'The Godfather'}), confidence=0.8378378378378378, lift=8.901730342240256)]),
#  RelationRecord(items=frozenset({'Whiplash', 'The Godfather', 'Mission: Impossible'}), support=0.004399413411545127, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Godfather', 'Mission: Impossible'}), items_add=frozenset({'Whiplash'}), confidence=0.7674418604651163, lift=7.864182234083111), OrderedStatistic(items_base=frozenset({'Whiplash', 'Mission: Impossible'}), items_add=frozenset({'The Godfather'}), confidence=0.8461538461538461, lift=8.990084985835693)]),
#  RelationRecord(items=frozenset({'The Hunger Games', 'Mission: Impossible', 'The Matrix'}), support=0.005865884548726837, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Hunger Games', 'Mission: Impossible'}), items_add=frozenset({'The Matrix'}), confidence=0.8, lift=8.175476839237058), OrderedStatistic(items_base=frozenset({'Mission: Impossible', 'The Matrix'}), items_add=frozenset({'The Hunger Games'}), confidence=0.7333333333333333, lift=7.858190476190476)]),
#  ...]

# %%
len(rules_list)
# Out:
# 4017

# %%
rules_list[0]
# Out:
# RelationRecord(items=frozenset({'Ant-Man', 'Black Panther'}), support=0.04906012531662445, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Ant-Man'}), items_add=frozenset({'Black Panther'}), confidence=0.5542168674698795, lift=6.260814341704166), OrderedStatistic(items_base=frozenset({'Black Panther'}), items_add=frozenset({'Ant-Man'}), confidence=0.5542168674698795, lift=6.260814341704166)])

# %%
rules_list[0][0]
# Out:
# frozenset({'Ant-Man', 'Black Panther'})

# %%
rules_list[0][2]
# Out:
# [OrderedStatistic(items_base=frozenset({'Ant-Man'}), items_add=frozenset({'Black Panther'}), confidence=0.5542168674698795, lift=6.260814341704166),
#  OrderedStatistic(items_base=frozenset({'Black Panther'}), items_add=frozenset({'Ant-Man'}), confidence=0.5542168674698795, lift=6.260814341704166)]

# %%
rules_list[0][2][0][3]
# Out:
# 6.260814341704166

# %%
def inspect(rules):
    lhs = [tuple(rule[0])[0] for rule in rules]
    rhs = [tuple(rule[0])[1] for rule in rules]
    supports = [rule[1] for rule in rules]
    confidences = [rule[2][0][2] for rule in rules]
    lifts = [rule[2][0][3] for rule in rules]
    return list(zip(lhs, rhs, supports, confidences, lifts))
resultsinDataFrame = pd.DataFrame(inspect(rules_list), columns=['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift'])
resultsinDataFrame
# Out:
#            Left Hand Side          Right Hand Side   Support  Confidence  \
# 0                 Ant-Man            Black Panther  0.049060    0.554217
# 1                 Ant-Man          Captain America  0.051593    0.582831
# 2          Doctor Strange                  Ant-Man  0.045327    0.512048
# 3                 Ant-Man  Guardians of the Galaxy  0.048793    0.551205
# 4                 Ant-Man                 Iron Man  0.049593    0.560241
# ...                   ...                      ...       ...         ...
# 4012  Mission: Impossible                John Wick  0.003066    0.403509
# 4013   Mad Max: Fury Road      Mission: Impossible  0.003066    0.418182
# 4014   Mad Max: Fury Road      Mission: Impossible  0.003200    0.421053
# 4015   Mad Max: Fury Road      Mission: Impossible  0.003066    0.403509
# 4016   Mad Max: Fury Road      Mission: Impossible  0.003200    0.358209
#
#             Lift
# 0       6.260814
# 1       6.236545
# 2       5.918141
# 3       6.180250
# 4       6.179952
# ...          ...
# 4012  112.100715
# 4013  116.177104
# 4014  112.796992
# 4015  116.412281
# 4016  103.343284
#
# [4017 rows x 5 columns]

# %%
resultsinDataFrame.sort_values(by='Lift', ascending=False)
# Out:
#            Left Hand Side      Right Hand Side   Support  Confidence  \
# 2771           Fight Club  Mission: Impossible  0.003333    0.694444
# 2731           Fight Club  Mission: Impossible  0.003066    0.638889
# 2811  Mission: Impossible            John Wick  0.003066    0.575000
# 1589           Fight Club   The Social Network  0.003600    0.750000
# 3110  Mission: Impossible            John Wick  0.003066    0.511111
# ...                   ...                  ...       ...         ...
# 913          The Avengers             Twilight  0.003733    0.538462
# 912          The Avengers              Titanic  0.003466    0.500000
# 821          The Avengers  Mission: Impossible  0.003466    0.490566
# 805    Mad Max: Fury Road         The Avengers  0.003466    0.490566
# 1038         The Avengers              Titanic  0.003733    0.528302
#
#             Lift
# 2771  168.033154
# 2731  165.251916
# 2811  154.038393
# 1589  152.047297
# 3110  147.455556
# ...          ...
# 913     4.357066
# 912     4.330831
# 821     4.298757
# 805     4.293741
# 1038    4.274857
#
# [4017 rows x 5 columns]

# %% [markdown]
# ## FP-Growth

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import fpgrowth, association_rules

# %%
# One-Hot Encode using TransactionEncoder
te = TransactionEncoder()
te_array = te.fit(transactions).transform(transactions)
df_encoded = pd.DataFrame(te_array, columns=te.columns_)
df_encoded.head()
# Out:
#    Ant-Man  Aquaman  Avatar  Batman v Superman  Black Panther  \
# 0    False    False   False              False          False
# 1    False    False   False              False          False
# 2    False     True   False               True          False
# 3    False    False   False              False          False
# 4     True    False   False              False           True
#
#    Captain America   Coco  Deadpool  Doctor Strange  Fight Club  ...  \
# 0            False  False     False           False       False  ...
# 1            False  False     False           False       False  ...
# 2            False  False      True           False       False  ...
# 3            False  False     False            True       False  ...
# 4             True  False     False            True       False  ...
#
#    The Social Network   Thor  Titanic  Toy Story  Twilight     Up  Venom  \
# 0               False  False    False      False      True  False  False
# 1               False  False    False      False     False  False  False
# 2               False  False    False      False     False  False   True
# 3               False   True    False      False     False  False  False
# 4               False   True    False      False     False  False  False
#
#    WALL-E  Whiplash  Wonder Woman
# 0   False     False         False
# 1   False     False         False
# 2   False     False          True
# 3   False     False         False
# 4   False     False         False
#
# [5 rows x 46 columns]

# %%
df_encoded.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7501 entries, 0 to 7500
# Data columns (total 46 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Ant-Man                  7501 non-null   bool
#  1   Aquaman                  7501 non-null   bool
#  2   Avatar                   7501 non-null   bool
#  3   Batman v Superman        7501 non-null   bool
#  4   Black Panther            7501 non-null   bool
#  5   Captain America          7501 non-null   bool
#  6   Coco                     7501 non-null   bool
#  7   Deadpool                 7501 non-null   bool
#  8   Doctor Strange           7501 non-null   bool
#  9   Fight Club               7501 non-null   bool
#  10  Finding Nemo             7501 non-null   bool
#  11  Forrest Gump             7501 non-null   bool
#  12  Frozen                   7501 non-null   bool
#  13  Gone Girl                7501 non-null   bool
#  14  Guardians of the Galaxy  7501 non-null   bool
#  15  Inception                7501 non-null   bool
#  16  Interstellar             7501 non-null   bool
#  17  Iron Man                 7501 non-null   bool
#  18  John Wick                7501 non-null   bool
#  19  Joker                    7501 non-null   bool
#  20  Jurassic Park            7501 non-null   bool
#  21  La La Land               7501 non-null   bool
#  22  Logan                    7501 non-null   bool
#  23  Mad Max: Fury Road       7501 non-null   bool
#  24  Man of Steel             7501 non-null   bool
#  25  Mission: Impossible      7501 non-null   bool
#  26  Pulp Fiction             7501 non-null   bool
#  27  Shrek                    7501 non-null   bool
#  28  Spider-Man               7501 non-null   bool
#  29  Star Wars                7501 non-null   bool
#  30  The Avengers             7501 non-null   bool
#  31  The Dark Knight          7501 non-null   bool
#  32  The Godfather            7501 non-null   bool
#  33  The Hunger Games         7501 non-null   bool
#  34  The Lion King            7501 non-null   bool
#  35  The Matrix               7501 non-null   bool
#  36  The Social Network       7501 non-null   bool
#  37  Thor                     7501 non-null   bool
#  38  Titanic                  7501 non-null   bool
#  39  Toy Story                7501 non-null   bool
#  40  Twilight                 7501 non-null   bool
#  41  Up                       7501 non-null   bool
#  42  Venom                    7501 non-null   bool
#  43  WALL-E                   7501 non-null   bool
#  44  Whiplash                 7501 non-null   bool
#  45  Wonder Woman             7501 non-null   bool
# dtypes: bool(46)
# memory usage: 337.1 KB

# %%
#  Apply FP-Growth
frequent_itemsets = fpgrowth(df_encoded, min_support=0.01, use_colnames=True)

print("Frequent Itemsets (Top 20):")
frequent_itemsets.head(20)
# Out:
# Frequent Itemsets (Top 20):
#      support                              itemsets
# 0   0.130116             frozenset({The Avengers})
# 1   0.123584                 frozenset({Twilight})
# 2   0.090655                 frozenset({Iron Man})
# 3   0.089188  frozenset({Guardians of the Galaxy})
# 4   0.089988                    frozenset({Shrek})
# 5   0.089455          frozenset({The Dark Knight})
# 6   0.089055                 frozenset({Deadpool})
# 7   0.088921                    frozenset({Joker})
# 8   0.088388                    frozenset({Logan})
# 9   0.087988             frozenset({Man of Steel})
# 10  0.087988                  frozenset({Aquaman})
# 11  0.087722                    frozenset({Venom})
# 12  0.084522        frozenset({Batman v Superman})
# 13  0.083989             frozenset({Wonder Woman})
# 14  0.088655                     frozenset({Thor})
# 15  0.086522           frozenset({Doctor Strange})
# 16  0.093454          frozenset({Captain America})
# 17  0.088522                  frozenset({Ant-Man})
# 18  0.088522            frozenset({Black Panther})
# 19  0.095587                frozenset({Toy Story})

# %%
frequent_itemsets.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1536 entries, 0 to 1535
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   support   1536 non-null   float64
#  1   itemsets  1536 non-null   object
# dtypes: float64(1), object(1)
# memory usage: 24.1+ KB

# %%
#  Generate association rules
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)

print("\nAssociation Rules (Top 20):")
rules.head(20)
# Out:
# Association Rules (Top 20):
#                                           antecedents  \
# 0                           frozenset({The Avengers})
# 1                               frozenset({Iron Man})
# 2                        frozenset({Captain America})
# 3                               frozenset({Iron Man})
# 4          frozenset({The Avengers, Captain America})
# 5                 frozenset({The Avengers, Iron Man})
# 6              frozenset({Captain America, Iron Man})
# 7                           frozenset({The Avengers})
# 8                        frozenset({Captain America})
# 9                               frozenset({Iron Man})
# 10                          frozenset({The Avengers})
# 11               frozenset({Guardians of the Galaxy})
# 12               frozenset({Guardians of the Galaxy})
# 13                              frozenset({Iron Man})
# 14                       frozenset({Captain America})
# 15               frozenset({Guardians of the Galaxy})
# 16  frozenset({The Avengers, Guardians of the Gala...
# 17                frozenset({The Avengers, Iron Man})
# 18     frozenset({Guardians of the Galaxy, Iron Man})
# 19                          frozenset({The Avengers})
#
#                                        consequents  antecedent support  \
# 0                            frozenset({Iron Man})            0.130116
# 1                        frozenset({The Avengers})            0.090655
# 2                            frozenset({Iron Man})            0.093454
# 3                     frozenset({Captain America})            0.090655
# 4                            frozenset({Iron Man})            0.070791
# 5                     frozenset({Captain America})            0.067324
# 6                        frozenset({The Avengers})            0.053060
# 7           frozenset({Captain America, Iron Man})            0.130116
# 8              frozenset({The Avengers, Iron Man})            0.093454
# 9       frozenset({The Avengers, Captain America})            0.090655
# 10            frozenset({Guardians of the Galaxy})            0.130116
# 11                       frozenset({The Avengers})            0.089188
# 12                           frozenset({Iron Man})            0.089188
# 13            frozenset({Guardians of the Galaxy})            0.090655
# 14            frozenset({Guardians of the Galaxy})            0.093454
# 15                    frozenset({Captain America})            0.089188
# 16                           frozenset({Iron Man})            0.066391
# 17            frozenset({Guardians of the Galaxy})            0.067324
# 18                       frozenset({The Avengers})            0.048793
# 19  frozenset({Guardians of the Galaxy, Iron Man})            0.130116
#
#     consequent support   support  confidence      lift  representativity  \
# 0             0.090655  0.067324    0.517418  5.707577               1.0
# 1             0.130116  0.067324    0.742647  5.707577               1.0
# 2             0.090655  0.053060    0.567760  6.262898               1.0
# 3             0.093454  0.053060    0.585294  6.262898               1.0
# 4             0.090655  0.044661    0.630885  6.959220               1.0
# 5             0.093454  0.044661    0.663366  7.098304               1.0
# 6             0.130116  0.044661    0.841709  6.468910               1.0
# 7             0.053060  0.044661    0.343238  6.468910               1.0
# 8             0.067324  0.044661    0.477889  7.098304               1.0
# 9             0.070791  0.044661    0.492647  6.959220               1.0
# 10            0.089188  0.066391    0.510246  5.721008               1.0
# 11            0.130116  0.066391    0.744395  5.721008               1.0
# 12            0.090655  0.048793    0.547085  6.034832               1.0
# 13            0.089188  0.048793    0.538235  6.034832               1.0
# 14            0.089188  0.050660    0.542083  6.077971               1.0
# 15            0.093454  0.050660    0.568012  6.077971               1.0
# 16            0.090655  0.040795    0.614458  6.778012               1.0
# 17            0.089188  0.040795    0.605941  6.793962               1.0
# 18            0.130116  0.040795    0.836066  6.425541               1.0
# 19            0.048793  0.040795    0.313525  6.425541               1.0
#
#     leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0   0.055529    1.884334       0.948166  0.438749   0.469308    0.630033
# 1   0.055529    3.380121       0.907020  0.438749   0.704153    0.630033
# 2   0.044588    2.103799       0.926958  0.404883   0.524669    0.576527
# 3   0.044588    2.185997       0.924104  0.404883   0.542543    0.576527
# 4   0.038243    2.463584       0.921542  0.382420   0.594087    0.561766
# 5   0.038369    2.692974       0.921136  0.384615   0.628663    0.570628
# 6   0.037757    5.495458       0.892785  0.322425   0.818032    0.592473
# 7   0.037757    1.441831       0.971870  0.322425   0.306438    0.592473
# 8   0.038369    1.786354       0.947687  0.384615   0.440201    0.570628
# 9   0.038243    1.831485       0.941673  0.382420   0.453995    0.561766
# 10  0.054786    1.859733       0.948639  0.434176   0.462288    0.627320
# 11  0.054786    3.403230       0.906011  0.434176   0.706162    0.627320
# 12  0.040708    2.007763       0.915991  0.372330   0.501933    0.542660
# 13  0.040708    1.972459       0.917468  0.372330   0.493019    0.542660
# 14  0.042325    1.989032       0.921599  0.383838   0.497243    0.555047
# 15  0.042325    2.098544       0.917282  0.383838   0.523479    0.555047
# 16  0.034776    2.358615       0.913085  0.350917   0.576022    0.532229
# 17  0.034790    2.311357       0.914370  0.352535   0.567354    0.531670
# 18  0.034446    5.306292       0.887684  0.295367   0.811545    0.574795
# 19  0.034446    1.385638       0.970671  0.295367   0.278311    0.574795

# %%
rules.sort_values(by='lift', ascending=False).head(20)
# Out:
#                                              antecedents  \
# 25661  frozenset({Spider-Man, Ant-Man, Doctor Strange...
# 25888  frozenset({Thor, Captain America, Iron Man, Gu...
# 25817  frozenset({Spider-Man, Captain America, Iron M...
# 25732  frozenset({Ant-Man, Doctor Strange, Guardians ...
# 25779  frozenset({Doctor Strange, Spider-Man, Black P...
# 25770  frozenset({Captain America, Guardians of the G...
# 25838  frozenset({Doctor Strange, Ant-Man, Black Pant...
# 25711  frozenset({Spider-Man, Captain America, Thor, ...
# 25690  frozenset({Spider-Man, Doctor Strange, Captain...
# 25859  frozenset({The Avengers, Ant-Man, Black Panthe...
# 25843  frozenset({Doctor Strange, Ant-Man, Black Pant...
# 25706  frozenset({Spider-Man, Captain America, Guardi...
# 25761  frozenset({Doctor Strange, Captain America, Th...
# 25788  frozenset({Spider-Man, Black Panther, Ant-Man,...
# 25872  frozenset({Doctor Strange, Captain America, Ir...
# 25677  frozenset({Spider-Man, Ant-Man, Guardians of t...
# 25742  frozenset({Ant-Man, Captain America, Guardians...
# 25807  frozenset({Doctor Strange, Spider-Man, Iron Ma...
# 25891  frozenset({Captain America, Black Panther, Iro...
# 25738  frozenset({Ant-Man, Doctor Strange, The Avenge...
#
#                                              consequents  antecedent support  \
# 25661  frozenset({Thor, Captain America, Iron Man, Gu...            0.019731
# 25888  frozenset({Spider-Man, Ant-Man, Doctor Strange...            0.024797
# 25817  frozenset({Ant-Man, Doctor Strange, Guardians ...            0.024797
# 25732  frozenset({Spider-Man, Captain America, Iron M...            0.019731
# 25779  frozenset({Captain America, Guardians of the G...            0.021730
# 25770  frozenset({Doctor Strange, Spider-Man, Black P...            0.022930
# 25838  frozenset({Spider-Man, Captain America, Thor, ...            0.021730
# 25711  frozenset({Doctor Strange, Ant-Man, Black Pant...            0.023064
# 25690  frozenset({The Avengers, Ant-Man, Black Panthe...            0.018797
# 25859  frozenset({Spider-Man, Doctor Strange, Captain...            0.026663
# 25843  frozenset({Spider-Man, Captain America, Guardi...            0.026530
# 25706  frozenset({Doctor Strange, Ant-Man, Black Pant...            0.019064
# 25761  frozenset({Spider-Man, Black Panther, Ant-Man,...            0.023197
# 25788  frozenset({Doctor Strange, Captain America, Th...            0.021864
# 25872  frozenset({Spider-Man, Ant-Man, Guardians of t...            0.024930
# 25677  frozenset({Doctor Strange, Captain America, Ir...            0.020397
# 25742  frozenset({Doctor Strange, Spider-Man, Iron Ma...            0.021997
# 25807  frozenset({Ant-Man, Captain America, Guardians...            0.023197
# 25891  frozenset({Spider-Man, Ant-Man, Doctor Strange...            0.025597
# 25738  frozenset({Thor, Spider-Man, Captain America, ...            0.021330
#
#        consequent support   support  confidence       lift  representativity  \
# 25661            0.024797  0.011465    0.581081  23.433813               1.0
# 25888            0.019731  0.011465    0.462366  23.433813               1.0
# 25817            0.019731  0.011465    0.462366  23.433813               1.0
# 25732            0.024797  0.011465    0.581081  23.433813               1.0
# 25779            0.022930  0.011465    0.527607  23.009202               1.0
# 25770            0.021730  0.011465    0.500000  23.009202               1.0
# 25838            0.023064  0.011465    0.527607  22.876201               1.0
# 25711            0.021730  0.011465    0.497110  22.876201               1.0
# 25690            0.026663  0.011465    0.609929  22.875390               1.0
# 25859            0.018797  0.011465    0.430000  22.875390               1.0
# 25843            0.019064  0.011465    0.432161  22.668799               1.0
# 25706            0.026530  0.011465    0.601399  22.668799               1.0
# 25761            0.021864  0.011465    0.494253  22.606041               1.0
# 25788            0.023197  0.011465    0.524390  22.606041               1.0
# 25872            0.020397  0.011465    0.459893  22.546783               1.0
# 25677            0.024930  0.011465    0.562092  22.546783               1.0
# 25742            0.023197  0.011465    0.521212  22.469035               1.0
# 25807            0.021997  0.011465    0.494253  22.469035               1.0
# 25891            0.019997  0.011465    0.447917  22.398819               1.0
# 25738            0.023997  0.011465    0.537500  22.398819               1.0
#
#        leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 25661  0.010976    2.327905       0.976596  0.346774   0.570429    0.521723
# 25888  0.010976    1.823301       0.981669  0.346774   0.451544    0.521723
# 25817  0.010976    1.823301       0.981669  0.346774   0.451544    0.521723
# 25732  0.010976    2.327905       0.976596  0.346774   0.570429    0.521723
# 25779  0.010967    2.068342       0.977787  0.345382   0.516521    0.513804
# 25770  0.010967    1.956539       0.978988  0.345382   0.488893    0.513804
# 25838  0.010964    2.068060       0.977529  0.344000   0.516455    0.512359
# 25711  0.010964    1.945295       0.978863  0.344000   0.485939    0.512359
# 25690  0.010964    2.495282       0.974605  0.337255   0.599244    0.519965
# 25859  0.010964    1.721408       0.982481  0.337255   0.419080    0.519965
# 25843  0.010959    1.727489       0.981937  0.335938   0.421125    0.516780
# 25706  0.010959    2.442215       0.974464  0.335938   0.590536    0.516780
# 25761  0.010958    1.934042       0.978461  0.341270   0.482948    0.509322
# 25788  0.010958    2.053791       0.977128  0.341270   0.513096    0.509322
# 25872  0.010957    1.813720       0.980081  0.338583   0.448647    0.510992
# 25677  0.010957    2.226652       0.975546  0.338583   0.550895    0.510992
# 25742  0.010955    2.040158       0.976985  0.339921   0.509842    0.507732
# 25807  0.010955    1.933779       0.978185  0.339921   0.482878    0.507732
# 25891  0.010953    1.775099       0.980451  0.335938   0.436651    0.510625
# 25738  0.010953    2.110277       0.976177  0.338583   0.526129    0.507639

# %%
def get_closed_patterns(frequent_itemsets):
    closed_patterns = []

    for i, row_i in frequent_itemsets.iterrows():
        is_closed = True
        
        for j, row_j in frequent_itemsets.iterrows():
            if row_i['itemsets'] < row_j['itemsets']:  # proper subset
                if row_i['support'] <= row_j['support']:
                    is_closed = False
                    break
                    
        if is_closed:
            closed_patterns.append(row_i)

    return pd.DataFrame(closed_patterns)

closed_itemsets = get_closed_patterns(frequent_itemsets)
print("Closed Itemsets (Top 20):")
closed_itemsets.head(20)
# Out:
# Closed Itemsets (Top 20):
#      support                              itemsets
# 0   0.130116             frozenset({The Avengers})
# 1   0.123584                 frozenset({Twilight})
# 2   0.090655                 frozenset({Iron Man})
# 3   0.089188  frozenset({Guardians of the Galaxy})
# 4   0.089988                    frozenset({Shrek})
# 5   0.089455          frozenset({The Dark Knight})
# 6   0.089055                 frozenset({Deadpool})
# 7   0.088921                    frozenset({Joker})
# 8   0.088388                    frozenset({Logan})
# 9   0.087988             frozenset({Man of Steel})
# 10  0.087988                  frozenset({Aquaman})
# 11  0.087722                    frozenset({Venom})
# 12  0.084522        frozenset({Batman v Superman})
# 13  0.083989             frozenset({Wonder Woman})
# 14  0.088655                     frozenset({Thor})
# 15  0.086522           frozenset({Doctor Strange})
# 16  0.093454          frozenset({Captain America})
# 17  0.088522                  frozenset({Ant-Man})
# 18  0.088522            frozenset({Black Panther})
# 19  0.095587                frozenset({Toy Story})

# %%
def get_max_patterns(frequent_itemsets):
    max_patterns = []
    for i, row_i in frequent_itemsets.iterrows():
        is_max = True
        for j, row_j in frequent_itemsets.iterrows():
            if row_i['itemsets'] < row_j['itemsets']:  # proper subset
                is_max = False
                break
        if is_max:
            max_patterns.append(row_i)
    return pd.DataFrame(max_patterns)

max_itemsets = get_max_patterns(frequent_itemsets)
print("Maximal Itemsets (Top 20):")
max_itemsets.head(20)
# Out:
# Maximal Itemsets (Top 20):
#       support                                           itemsets
# 206  0.011998  frozenset({Joker, Venom, Man of Steel, Deadpoo...
# 270  0.011732  frozenset({Batman v Superman, Venom, Man of St...
# 302  0.011332  frozenset({Batman v Superman, Joker, Man of St...
# 318  0.011998  frozenset({Batman v Superman, Joker, Venom, De...
# 330  0.011199  frozenset({Batman v Superman, Joker, Venom, Ma...
# 331  0.011598  frozenset({Batman v Superman, Joker, Venom, Ma...
# 332  0.011065  frozenset({Batman v Superman, Joker, Venom, Ma...
# 397  0.011598  frozenset({Joker, Venom, Wonder Woman, Man of ...
# 429  0.012265  frozenset({Batman v Superman, Joker, Man of St...
# 445  0.011865  frozenset({Batman v Superman, Joker, Venom, Wo...
# 453  0.011199  frozenset({Batman v Superman, Joker, Venom, Wo...
# 458  0.011598  frozenset({Batman v Superman, Joker, Venom, Wo...
# 459  0.011332  frozenset({Batman v Superman, Venom, Wonder Wo...
# 492  0.011332  frozenset({Batman v Superman, Venom, Wonder Wo...
# 516  0.011598  frozenset({Batman v Superman, Venom, Wonder Wo...
# 520  0.011065  frozenset({Batman v Superman, Venom, Wonder Wo...
# 521  0.011465  frozenset({Batman v Superman, Man of Steel, Wo...
# 522  0.011065  frozenset({Venom, Wonder Woman, Man of Steel, ...
# 539  0.011065  frozenset({Joker, Venom, Wonder Woman, Man of ...
# 547  0.011199  frozenset({Joker, Man of Steel, Wonder Woman, ...

# %% [markdown]
# ## PageRank

# %%
from collections import defaultdict
from itertools import combinations
import networkx as nx
import pandas as pd

# %%
# ── Step 1: بناء الـ co-watch graph ──────────────────────────────────────
co_watch = defaultdict(lambda: defaultdict(int))

for session in transactions:
    unique = list(set(session))
    for a, b in combinations(unique, 2):
        co_watch[a][b] += 1   # a و b اتشافوا مع بعض
        co_watch[b][a] += 1

# %%
# ── Step 2: تحويله لـ NetworkX Graph ─────────────────────────────────────
G = nx.DiGraph()

for movie_a in co_watch:
    for movie_b, weight in co_watch[movie_a].items():
        G.add_edge(movie_a, movie_b, weight=weight)

print(f"Movies (nodes) : {G.number_of_nodes()}")
print(f"Co-watch pairs : {G.number_of_edges()}")
# Out:
# Movies (nodes) : 46
# Co-watch pairs : 2070

# %%
# ── Step 3: PageRank ──────────────────────────────────────────────────────
pr_scores = nx.pagerank(G, alpha=0.85, weight='weight')

# %%
# ── Step 4: النتيجة ───────────────────────────────────────────────────────
pagerank_df = (
    pd.DataFrame(list(pr_scores.items()), columns=['Movie', 'PageRank'])
    .sort_values('PageRank', ascending=False)
    .reset_index(drop=True)
)

print("\nTop 10 Most Important Movies:")
print(pagerank_df.head(10).to_string(index=False))
# Out:
# Top 10 Most Important Movies:
#           Movie  PageRank
#    The Avengers  0.028971
# Captain America  0.023279
#       Toy Story  0.022691
#      The Matrix  0.022634
# The Dark Knight  0.022563
#        Iron Man  0.022519
#   Black Panther  0.022416
#            Thor  0.022372
#           Logan  0.022349
#           Joker  0.022349

# %% [markdown]
# ## Visualization 3: Top 20 Movies by PageRank

# %%
top_pr =pagerank_df.head(20)

plt.figure(figsize=(12, 6))
colors_pr = plt.cm.plasma([i/20 for i in range(20)])
plt.barh(top_pr['Movie'][::-1], top_pr['PageRank'][::-1], color=colors_pr[::-1])
plt.title('Top 20 Movies Ranked by PageRank (Co-Watch Graph)', fontsize=14, fontweight='bold')
plt.xlabel('PageRank Score')
plt.tight_layout()
plt.savefig('pagerank_top20.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Visualization 4: Frequent Movie Pair Co-Watch Graph

# %%
# Build edge list: top 30 pairs by co-watch count
edge_list = []
for a in co_watch:
    for b, w in co_watch[a].items():
        if a < b:
            edge_list.append((a, b, w))

edge_list.sort(key=lambda x: -x[2])
top_edges = edge_list[:30]

# Collect top nodes
top_nodes = set()
for a, b, _ in top_edges:
    top_nodes.add(a)
    top_nodes.add(b)
top_nodes = sorted(top_nodes)
n_nodes = len(top_nodes)
node_idx = {n: i for i, n in enumerate(top_nodes)}

# Circular layout
import math
angles = [2 * math.pi * i / n_nodes for i in range(n_nodes)]
pos = {node: (math.cos(angles[i]) * 3, math.sin(angles[i]) * 3)
       for i, node in enumerate(top_nodes)}

fig, ax = plt.subplots(figsize=(14, 14))
ax.set_aspect('equal')
ax.axis('off')
ax.set_title('Frequent Movie Pair Co-Watch Network (Top 30 Pairs)', fontsize=14, fontweight='bold')

max_w = max(w for _, _, w in top_edges)
min_w = min(w for _, _, w in top_edges)

# Draw edges
for a, b, w in top_edges:
    x1, y1 = pos[a]
    x2, y2 = pos[b]
    lw = 0.5 + 3.5 * (w - min_w) / (max_w - min_w + 1)
    alpha = 0.3 + 0.6 * (w - min_w) / (max_w - min_w + 1)
    ax.plot([x1, x2], [y1, y2], color='#457b9d', linewidth=lw, alpha=alpha, zorder=1)

# Draw nodes
pr_lookup = dict(zip(pagerank_df['Movie'], pagerank_df['PageRank']))
max_pr = pagerank_df['PageRank'].max()
for node, (x, y) in pos.items():
    pr = pr_lookup.get(node, 0)
    size = 200 + 1000 * (pr / max_pr)
    ax.scatter(x, y, s=size, c='#e63946', zorder=3, edgecolors='white', linewidths=1.5)
    ax.annotate(node, (x, y), textcoords='offset points',
                xytext=(0, 8), ha='center', fontsize=7, fontweight='bold')

plt.tight_layout()
plt.savefig('cowatch_graph.png', dpi=150, bbox_inches='tight')
plt.show()
print("Co-watch pair graph saved.")
# Out:
# Co-watch pair graph saved.

# %% [markdown]
# ## Final Combined Ranking: Popularity + PageRank

# %%
from collections import Counter

pop_counts = Counter(m for s in transactions for m in s)
pop_df = pd.DataFrame(list(pop_counts.items()), columns=['Movie', 'Watch_Count'])
pop_df['Watch_Count_Norm'] = pop_df['Watch_Count'] / pop_df['Watch_Count'].max()

combined = pagerank_df.merge(pop_df, on='Movie')
combined['PageRank_Norm'] = combined['PageRank'] / combined['PageRank'].max()
combined['Combined_Score'] = 0.5 * combined['PageRank_Norm'] + 0.5 * combined['Watch_Count_Norm']
combined = combined.sort_values('Combined_Score', ascending=False).reset_index(drop=True)
combined[['Movie','Watch_Count','PageRank','Combined_Score']].head(20)
# Out:
#                  Movie  Watch_Count  PageRank  Combined_Score
# 0         The Avengers         1364  0.028971        1.000000
# 1             Twilight          927  0.019489        0.676166
# 2           The Matrix          734  0.022634        0.659684
# 3      Captain America          701  0.023279        0.658731
# 4            Toy Story          717  0.022691        0.654444
# 5         Interstellar          734  0.022299        0.653906
# 6             Whiplash          732  0.022033        0.648586
# 7           La La Land          879  0.018878        0.648020
# 8              Titanic          866  0.018818        0.642213
# 9        The Lion King          703  0.022258        0.641837
# 10              Avatar          721  0.021863        0.641613
# 11        Finding Nemo          701  0.022278        0.641445
# 12           John Wick          854  0.018963        0.640323
# 13        Forrest Gump          719  0.021700        0.638076
# 14            Iron Man          680  0.022519        0.637915
# 15       Jurassic Park          709  0.021847        0.636937
# 16  Mad Max: Fury Road          857  0.018680        0.636542
# 17    The Hunger Games          700  0.021981        0.635952
# 18        Pulp Fiction          719  0.021547        0.635438
# 19     The Dark Knight          671  0.022563        0.635366

# %% [markdown]
# ## Visualization 5: Apriori vs FP-Growth Rules — Support vs Confidence

# %%
import pandas as pd

results = []

for item in rules_list:
    pair = item[0]
    support = item[1]

    for stat in item[2]:
        antecedent = list(stat[0])
        consequent = list(stat[1])
        confidence = stat[2]
        lift = stat[3]

        results.append({
            'antecedents': antecedent,
            'consequents': consequent,
            'support': support,
            'confidence': confidence,
            'lift': lift
        })

rules_df = pd.DataFrame(results)

print(rules_df.head())
# Out:
#          antecedents        consequents   support  confidence      lift
# 0          [Ant-Man]    [Black Panther]  0.049060    0.554217  6.260814
# 1    [Black Panther]          [Ant-Man]  0.049060    0.554217  6.260814
# 2          [Ant-Man]  [Captain America]  0.051593    0.582831  6.236545
# 3  [Captain America]          [Ant-Man]  0.051593    0.552068  6.236545
# 4          [Ant-Man]   [Doctor Strange]  0.045327    0.512048  5.918141

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(7, 5))

if len(rules_df) == 0:
    ax.set_title('No rules found')
else:
    sc = ax.scatter(
        rules_df['support'],
        rules_df['confidence'],
        c=rules_df['lift'],
        cmap='viridis',
        alpha=0.7,
        edgecolors='k',
        linewidths=0.3
    )

    ax.set_xlabel('Support')
    ax.set_ylabel('Confidence')
    ax.set_title(f'Apriori Rules ({len(rules_df)} rules)')

    plt.colorbar(sc, ax=ax, label='Lift')

plt.tight_layout()
plt.savefig('rules_scatter.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# !pip install transformers torch scikit-learn pandas numpy
# Out:
# Requirement already satisfied: transformers in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (5.6.0)
# Requirement already satisfied: torch in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (2.11.0)
# Requirement already satisfied: scikit-learn in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (1.8.0)
# Requirement already satisfied: pandas in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (3.0.2)
# Requirement already satisfied: numpy in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (2.4.4)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from transformers) (1.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from transformers) (2026.4.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from transformers) (0.24.2)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from transformers) (4.67.3)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (3.25.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (2026.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: anyio in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.12.1)
# Requirement already satisfied: certifi in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: setuptools<82 in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from torch) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: click>=8.2.1 in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from typer->transformers) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from typer->transformers) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from rich>=12.3.0->typer->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from rich>=12.3.0->typer->transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers) (0.1.2)
# [notice] A new release of pip is available: 25.3 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np

df2= pd.read_csv('IMDB Dataset.csv')
print(df2.shape)
df2.head()
# Out:
# (50000, 2)
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
print(df2['sentiment'].value_counts())
# Out:
# sentiment
# positive    25000
# negative    25000
# Name: count, dtype: int64

# %%
import re

# تحويل positive/negative لـ 1/0
df2['label'] = df2['sentiment'].map({'positive': 1, 'negative': 0})

# تنظيف HTML tags زي <br />
def clean_text(text):
    text = re.sub(r'<.*?>', ' ', text)   # شيل HTML
    text = re.sub(r'\s+', ' ', text)     # شيل مسافات زيادة
    return text.strip()

df2['review'] = df2['review'].apply(clean_text)

print(df2[['review', 'label']].head(3))
# Out:
#                                               review  label
# 0  One of the other reviewers has mentioned that ...      1
# 1  A wonderful little production. The filming tec...      1
# 2  I thought this was a wonderful way to spend ti...      1

# %%
df2_train = df2[df2['sentiment'] == 'positive'].head(500).copy()
df2_train = pd.concat([df2_train, df2[df2['sentiment'] == 'negative'].head(500)])
df2_train = df2_train.sample(frac=1, random_state=42).reset_index(drop=True)

df2_test = df2[df2['sentiment'] == 'positive'].iloc[50:55].copy()
df2_test = pd.concat([df2_test, df2[df2['sentiment'] == 'negative'].iloc[50:55]])
df2_test = df2_test.reset_index(drop=True)

x_train_text = df2_train['review'].tolist()
y_train      = df2_train['label'].tolist()

x_test_text  = df2_test['review'].tolist()
y_test       = df2_test['label'].tolist()

print(f"Train: {len(x_train_text)} — Test: {len(x_test_text)}")
print("مثال:", x_train_text[0][:100], "...")
# Out:
# Train: 1000 — Test: 10
# مثال: It had all the clichés of movies of this type and no substance. The plot went nowhere and at the end ...

# %%
from transformers import BertTokenizer

tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

train_encodings = tokenizer(
    x_train_text,
    truncation=True,
    padding=True,
    max_length=128
)

test_encodings = tokenizer(
    x_test_text,
    truncation=True,
    padding=True,
    max_length=128
)

print("✅ Tokenization ")
print(" encoding:", list(train_encodings.keys()))
# Out:
# ✅ Tokenization
#  encoding: ['input_ids', 'token_type_ids', 'attention_mask']

# %%
import torch

class IMDbDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels    = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

train_dataset = IMDbDataset(train_encodings, y_train)
test_dataset  = IMDbDataset(test_encodings,  y_test)

print(f"✅ Train size: {len(train_dataset)} — Test size: {len(test_dataset)}")
# Out:
# ✅ Train size: 1000 — Test size: 10

# %%
from transformers import BertForSequenceClassification

model = BertForSequenceClassification.from_pretrained(
    'bert-base-uncased',
    num_labels=2      # positive أو negative
)

print("✅ BERT  load")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100%|██████████| 199/199 [00:00<00:00, 2759.58it/s]
# [transformers] BertForSequenceClassification LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.seq_relationship.bias                  | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# cls.seq_relationship.weight                | UNEXPECTED |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# classifier.bias                            | MISSING    |
# classifier.weight                          | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# ✅ BERT  load

# %%
# !pip install "accelerate>=1.1.0" -q
# !pip install "transformers[torch]" -q
# !pip install torch -q
# Out:
# [notice] A new release of pip is available: 25.3 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip is available: 25.3 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip is available: 25.3 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from transformers import TrainingArguments, Trainer

training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=2,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    logging_dir='./logs',
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
)
# Out:
# [transformers] `logging_dir` is deprecated and will be removed in v5.2. Please set `TENSORBOARD_LOGGING_DIR` instead.

# %%
trainer.train()
# Out:
# c:\Users\HP\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\torch\utils\data\dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
#     <div>
#
#       <progress value='250' max='250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [250/250 21:07, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.06it/s]
# TrainOutput(global_step=250, training_loss=0.33527536010742187, metrics={'train_runtime': 1282.2565, 'train_samples_per_second': 1.56, 'train_steps_per_second': 0.195, 'total_flos': 131555527680000.0, 'train_loss': 0.33527536010742187, 'epoch': 2.0})

# %%
results = trainer.evaluate()
print(results)
# Out:
# c:\Users\HP\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\torch\utils\data\dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
#     <div>
#
#       <progress value='2' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2/2 00:00]
#     </div>
# <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Step</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>No log</td>
#       <td>0.007692</td>
#       <td>250</td>
#     </tr>
#   </tbody>
# </table><p>
# {'eval_loss': 0.007692014332860708}

# %%
def predict_sentiment(review_text):
    inputs = tokenizer(
        review_text,
        return_tensors='pt',
        truncation=True,
        padding=True,
        max_length=128
    )

    model.eval()
    with torch.no_grad():
        outputs = model(**inputs)

    probs = torch.softmax(outputs.logits, dim=1)
    pred  = torch.argmax(probs).item()
    conf  = probs[0][pred].item() * 100

    label = 'Positive ✅' if pred == 1 else 'Negative ❌'
    print(f"Review  : {review_text[:80]}...")
    print(f"Result  : {label}")
    print(f"Confidence: {conf:.1f}%")
    print("-" * 50)


# تجربة
predict_sentiment("This movie was absolutely amazing, best film I have seen in years!")
predict_sentiment("Terrible movie, complete waste of time. Boring and predictable.")
# Out:
# Review  : This movie was absolutely amazing, best film I have seen in years!...
# Result  : Positive ✅
# Confidence: 99.6%
# --------------------------------------------------
# Review  : Terrible movie, complete waste of time. Boring and predictable....
# Result  : Negative ❌
# Confidence: 99.5%
# --------------------------------------------------
